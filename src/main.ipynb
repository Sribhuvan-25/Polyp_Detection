# %%
from setup import *

# %%
import pandas as pd
import numpy as np
import cv2
from read_roi import read_roi_file
import os
import random

# Define the functions here (assumed to be already provided)

def detect_features_in_channel(channel):
    features = cv2.goodFeaturesToTrack(channel, maxCorners=200, qualityLevel=0.01, minDistance=50, blockSize=300)
    if features is not None:
        return np.int0(features)
    else:
        return np.array([])

def filter_close_points(features, min_dist=100):
    if features.ndim == 3:
        features = features.reshape(-1, 2)
    
    filtered_points = []

    for feature in features:
        if not filtered_points:
            filtered_points.append(feature)
            continue

        dists = np.sqrt(np.sum((np.array(filtered_points) - feature) ** 2, axis=1))

        if np.all(dists >= min_dist):
            filtered_points.append(feature)

    return np.array(filtered_points)

def bounding_box(roi_file_path):
    roi = read_roi_file(roi_file_path)
    for box_info in roi.values():
        if box_info['type'] == 'rectangle':
            left = box_info['left']
            top = box_info['top']
            width = box_info['width']
            height = box_info['height']
    print(left, top, width, height)
    return left, top, width, height

def extract_patch(image, center_x, center_y, patch_size):
    half_width, half_height = patch_size[0] // 2, patch_size[1] // 2
    patch = image[
        center_y - half_height:center_y + half_height,
        center_x - half_width:center_x + half_width
    ]
    return patch

def extract_patches_from_abnormal(image_path, roi_file_path, patch_size=(100, 100)):
    image = cv2.imread(image_path)
    print(f'Image:{image}')
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    left, top, width, height = bounding_box(roi_file_path)
    roi_region = gray_image[top:top+height, left:left+width]
    
    features = detect_features_in_channel(roi_region)
    
    if len(features) > 0:
        features[:, 0] += left
        features[:, 1] += top

        salient_points = filter_close_points(features)
        
        if len(salient_points) > 0:
            center_x, center_y = np.mean(salient_points, axis=0).astype(int)
            patch = extract_patch(image, center_x, center_y, patch_size)
            visualize_patch(image, center_x, center_y, patch_size)
            return patch, image
    
    center_x, center_y = left + width // 2, top + height // 2
    patch = extract_patch(image, center_x, center_y, patch_size)
    visualize_patch(image, center_x, center_y, patch_size)
    
    return patch, image

def extract_patches_from_normal(image_path, patch_size=(100, 100)):
    image = cv2.imread(image_path)
    h, w, _ = image.shape
    
    middle_x_range = (w // 4, 3 * w // 4)
    middle_y_range = (h // 4, 3 * h // 4)
    
    patches = []
    visualized_images = []
    for _ in range(2):
        center_x = random.randint(middle_x_range[0], middle_x_range[1])
        center_y = random.randint(middle_y_range[0], middle_y_range[1])
        patch = extract_patch(image, center_x, center_y, patch_size)
        patches.append(patch)
        
        visualize_patch(image, center_x, center_y, patch_size)
        visualized_images.append(image.copy())
    
    return patches, visualized_images

def visualize_patch(image, center_x, center_y, patch_size):
    half_width, half_height = patch_size[0] // 2, patch_size[1] // 2
    top_left = (center_x - half_width, center_y - half_height)
    bottom_right = (center_x + half_width, center_y + half_height)
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

def save_patches(patches, output_dir, base_name):
    for i, patch in enumerate(patches):
        patch_filename = f"{base_name}_patch_{i}.png"
        patch_path = os.path.join(output_dir, patch_filename)
        cv2.imwrite(patch_path, patch)

def save_visualized_images(images, output_dir, base_name):
    for i, img in enumerate(images):
        visualized_filename = f"{base_name}_visualized_{i}.png"
        visualized_path = os.path.join(output_dir, visualized_filename)
        cv2.imwrite(visualized_path, img)

def process_directory(input_dir, output_dir, visualized_dir, is_abnormal=False, patch_size=(100, 100)):
    print(f"Processing directory: {input_dir}")
    for filename in os.listdir(input_dir):
        print(filename)
        if filename.endswith('.png'):
            image_path = os.path.join(input_dir, filename)
            base_name = os.path.splitext(filename)[0]

            if is_abnormal:
                roi_file_path = os.path.join(input_dir, f"{base_name}.roi")
                patch, visualized_image = extract_patches_from_abnormal(image_path, roi_file_path, patch_size)
                save_patches([patch], output_dir, base_name)
                save_visualized_images([visualized_image], visualized_dir, base_name)
            else:
                patches, visualized_images = extract_patches_from_normal(image_path, patch_size)
                save_patches(patches, output_dir, base_name)
                save_visualized_images(visualized_images, visualized_dir, base_name)

# Define train and test directories
train_dir = '../Data/Split_Data/train'
test_dir = '../Data/Split_Data/test'

# Process the normal and abnormal directories in both train and test directories
for data_dir in [train_dir, test_dir]:
    for class_type in ['normal', 'abnormal']:
        input_dir = os.path.join(data_dir, class_type)
        print(input_dir)
        output_dir = os.path.join('Processed_Data', os.path.basename(data_dir), class_type)
        visualized_dir = os.path.join('Visualized_Data', os.path.basename(data_dir), class_type)
        os.makedirs(output_dir, exist_ok=True)
        os.makedirs(visualized_dir, exist_ok=True)
        process_directory(input_dir, output_dir, visualized_dir, is_abnormal=(class_type == 'abnormal'))

print("Patch extraction and visualization complete.")
# Out:
# ../Data/Split_Data/train/normal
# Processing directory: ../Data/Split_Data/train/normal
# 356-1-61-adenoma-D-0001.roi
# 037-1-74-adenoma-T-0002.jpg
# 102-1-76-polyp-S-0008.jpg
# 125-1-68-polyp-T-0005.roi
# 284-2-77-adenoma-HF-0001.roi
# 027-1-79-adenoma-T-0000.roi
# 043-1-53-adenoma-T-0001.jpg
# 513-1-59-adenoma-D-0001.roi
# 402-1-74-adenoma-D-0005.roi
# 287-1-60-adenoma-A-0001.roi
# 136-1-50-adenoma-C-0000.roi
# 429-1-54-adenoma-S-0004.jpg
# 146-2-62-adenoma-A-0000.jpg
# 311-1-58-adenoma-S-0001.jpg
# 527-1-54-adenoma-S-0001.roi
# 332-1-62-adenoma-HF,T-0002.jpg
# 188-2-78-adenoma-35cm-0000.jpg
# 097-1-76-adenoma-T-0001.jpg
# 292-1-65-adenoma-C-0001.roi
# 342-1-58-polyp-R-0001.jpg
# 496-2-84-adenoma-A-0002.jpg
# 314-1-72-adenoma-S-0003.jpg
# 537-1-63-adenoma-C-0002.roi
# 331-1-62-adenoma-A-0002.jpg
# 538-2-66-2-adenoma-T-0001.jpg
# 046-1-76-adenoma-R-0009.roi
# 167-1-54-adenoma-D-0000.roi
# 035-1-56-adenoma-R-0002.roi
# 127-1-63-adenoma-T-0001.jpg
# 122-2-60-adenoma-R-0000.roi
# 404-1-74-adenoma-S-0007.jpg
# 461-1-70-adenoma-D-0007.roi
# 142-2-64-adenoma-T-0003.roi
# 108-1-83-adenoma-D-0004.roi
# 483-1-71-adenoma-A-0002.roi
# 392-2-77-adenoma-S-0001.jpg
# 005-2-54-polyp-A-0000.jpg
# 204-2-52-adenoma-A-0000.roi
# 078-2-73-polyp-A-0002.roi
# 323-2-50-polyp-A-0001.roi
# 186-1-80-adenoma-A-0000.jpg
# 219-1-48-polyp-S-0001.roi
# 367-1-70-adenoma-HF-0001.roi
# 498-1-57-adenoma-R-0001.jpg
# 242-1-65-polyp-R-0001.roi
# 422-1-59-adenoma-S-0001.jpg
# 508-2-76-adenoma-AV20-0001.roi
# 264-2-50-adenoma-A-0001.roi
# 389-1-68-adenoma-A-0002.roi
# 051-1-67-adenoma-T-0000.jpg
# 536-1-63-adenoma-A-0004.roi
# 278-1-49-polyp-D-0002.roi
# 475-1-52-adenoma-T-0002.jpg
# 086-1-72-adenoma-A-0000.roi
# 401-1-74-adenoma-D-0003.jpg
# 029-1-80-adenoma-A-0000.jpg
# 189-2-69-adenoma-S-0000.jpg
# 319-1-66-adenoma-A-0002.jpg
# 071-1-62-adenoma-S-0004.zip
# 008-1-58-adenoma-T-0000.roi
# 413-1-55-adenoma-SF-0002.jpg
# 293-1-65-adenoma-R-0002.jpg
# 418-1-57-adenoma-S-0006.jpg
# 412-1-55-adenoma-S-0003.roi
# 026-2-57-adenoma-T-0000.roi
# .DS_Store
# 465-1-51-polyp-A-0002.jpg
# 458-1-70-adenoma-D-0004.jpg
# 515-2-56-adenoma-A-0001.jpg
# 540-1-51-adenoma-D-0001.jpg
# 220-1-48-tumor-A-0002.jpg
# 030-1-74-adenoma-HF-0000.jpg
# 151-1-58-adenoma-T-0000.jpg
# 430-1-73-adenoma-T-0001.roi
# 345-1-78-adenoma-A-0004.jpg
# 437-1-56-adenoma-T-0001.roi
# 112-1-78-adenoma-S-0001.jpg
# 156-1-53-polyp-20cm-0001.jpg
# 064-1-64-adenoma-A-0000.jpg
# 490-1-63-polyp-S-0004.jpg
# 446-2-84-adenoma-T-0002.roi
# 263-1-79-adenoma-T-0004.jpg
# 231-1-46-polyp-T-0002.jpg
# 088-2-76-polyp-A-0000.roi
# 417-1-57-adenoma-A-0003.roi
# 152-1-58-adenoma-T-0001.roi
# 346-1-78-adenoma-A-0005.roi
# 203-2-48-polyp-R-0000.jpg
# 340-2-41-adenoma-D-0002.roi
# 502-2-57-adenoma-HF-0001.jpg
# 288-1-60-polyp-T-0002.jpg
# 033-2-63-adenoma-A-0000.jpg
# 160-1-56-adenoma-RSJ-0000.jpg
# 453-2-76-adenoma-S-0006.roi
# 309-2-40-polyp-A-0001.jpg
# 067-1-57-adenoma-S-0000.jpg
# 196-2-44-adenoma-T-0000.jpg
# 454-2-76-adenoma-T-0002.roi
# 180-2-44-polyp-S-0000.roi
# 099-1-76-polyp-D-0005.roi
# 070-1-62-adenoma-S-0003.roi
# 328-2-64-adenoma-A-0002.roi
# 529-1-82-adenoma-D-0002.roi
# 478-1-60-adenoma-T-0001.jpg
# 532-1-56-adenoma-T-0001.jpg
# 221-1-49-adenoma-C-0003.roi
# 493-2-70-adenoma-A-0001.roi
# 409-2-54-adenoma-T-0001.jpg
# 195-2-54-adenoma-S-0003.jpg
# 218-1-48-adenoma-HF-0000.jpg
# 172-1-57-adenoma-S-0001.roi
# 099-1-76-polyp-D-0005.jpg
# 529-1-82-adenoma-D-0002.jpg
# 448-1-71-adenoma-A-0001.jpg
# 007-2-57-adenoma-S-0002.jpg
# 403-1-74-adenoma-S-0006.jpg
# 091-1-62-adenoma-T-0001.jpg
# 511-1-42-adenoma-T-0001.roi
# 164-2-55-lipoma-A-0001.jpg
# 478-1-60-adenoma-T-0001.roi
# 221-1-49-adenoma-C-0003.jpg
# 016-1-56-adenoma-D-0000.jpg
# 502-2-57-adenoma-HF-0001.roi
# 340-2-41-adenoma-D-0002.jpg
# 129-1-63-adenoma-C-0000.roi
# 426-1-54-adenoma-S-0001.roi
# 395-1-68-adenoma-T-0001.jpg
# 131-1-58-leiomyoma-D-0002.jpg
# 454-2-76-adenoma-T-0002.jpg
# 030-1-74-adenoma-HF-0000.roi
# 161-1-34-adenoma-S-0000.roi
# 430-1-73-adenoma-T-0001.jpg
# 183-1-59-adenoma-A-0000.jpg
# 200-1-62-adenoma-C-0000.jpg
# 490-1-63-polyp-S-0004.roi
# 049-1-57-adenoma-S-0001.jpg
# 231-1-46-polyp-T-0002.roi
# 263-1-79-adenoma-T-0004.roi
# 206-1-54-adenoma-HF-0000.roi
# 401-1-74-adenoma-D-0003.roi
# 536-1-63-adenoma-A-0004.jpg
# 081-2-71-adenoma-D-0001.jpg
# 432-1-51-adenoma-T-0001.jpg
# 319-1-66-adenoma-A-0002.roi
# 347-1-78-adenoma-AV30-0007.jpg
# 252-1-59-adenoma-A-0000.roi
# 202-1-81-adenoma-T-0000.jpg
# 026-2-57-adenoma-T-0000.jpg
# 418-1-57-adenoma-S-0006.roi
# 008-1-58-adenoma-T-0000.jpg
# 148-1-59-adenoma-R-0000.roi
# 147-2-68-adenoma-S-0000.jpg
# 498-1-57-adenoma-R-0001.roi
# 367-1-70-adenoma-HF-0001.jpg
# 463-1-70-adenoma-T-0003.jpg
# 015-1-65-polyp-S-0001.roi
# 113-1-78-polyp-R-0006.jpg
# 422-1-59-adenoma-S-0001.roi
# 242-1-65-polyp-R-0001.jpg
# 485-1-80-adenoma-S-0004.jpg
# 531-1-58-adenoma-T-0002.jpg
# 174-1-61-polyp-S-0001.jpg
# 389-1-68-adenoma-A-0002.jpg
# 038-2-75-adenoma-A-0001.jpg
# 167-1-54-adenoma-D-0000.jpg
# 046-1-76-adenoma-R-0009.jpg
# 271-1-62-polyp-R-0002.roi
# 256-2-45-adenoma-S-0001.roi
# 512-1-50-polyp-R-0003.jpg
# 291-1-54-adenoma-S-0003.roi
# 369-1-61-adenoma-A-0001.roi
# 142-2-64-adenoma-T-0003.jpg
# 461-1-70-adenoma-D-0007.jpg
# 404-1-74-adenoma-S-0007.roi
# 122-2-60-adenoma-R-0000.jpg
# 041-1-74-adenoma-A-0000.jpg
# 325-2-66-adenoma-T-0001.jpg
# 513-1-59-adenoma-D-0001.jpg
# 047-1-76-adenoma-RS-0001.roi
# 443-1-59-adenoma-R-0001.jpg
# 185-2-61-adenoma-T-0000.jpg
# 043-1-53-adenoma-T-0001.roi
# 181-1-50-adenoma-S-0000.jpg
# 339-2-41-adenoma-D-0001.roi
# 326-2-66-adenoma-T-0002.roi
# 146-2-62-adenoma-A-0000.roi
# 216-1-77-adenoma-S-0003.jpg
# 136-1-50-adenoma-C-0000.jpg
# 411-1-55-adenoma-R-0005.roi
# 103-1-42-adenoma-S-0000.jpg
# 335-1-72-adenoma-T-0002.roi
# 109-1-83-adenoma-T-0003.roi
# 297-1-65-adenoma-R-0003.roi
# 341-2-44-adenoma-A-0001.jpg
# 306-1-67-adenoma-RS-0002.roi
# 356-1-61-adenoma-D-0001.jpg
# 128-2-55-polyp-A-0000.jpg
# 145-1-60-polyp-D-0002.roi
# 254-2-50-polyp-R-0002.jpg
# 509-1-61-adenoma-A-0001.roi
# 209-2-75-adenoma-T-0001.roi
# 121-1-63-adenoma-D-0000.roi
# 107-1-83-adenoma-A-0001.jpg
# 135-1-70-adenoma-T-0001.jpg
# 056-1-75-adenoma-T-0002.jpg
# 139-2-64-adenoma-R-0000.jpg
# 062-1-59-adenoma-T-0000.roi
# 363-1-49-adenoma-T-0001.roi
# 324-2-53-adenoma-T-0001.jpg
# 079-2-73-polyp-A-0003.roi
# 249-1-21-polyp-A-0000.jpg
# 244-1-61-adenoma-A-0000.roi
# 337-2-75-adenoma-T-0001.roi
# 193-2-54-adenoma-A-0000.jpg
# 039-2-75-adenoma-R-0002.jpg
# 379-1-48-adenoma-S-0001.jpg
# 225-2-75-adenoma-A-0000.jpg
# 455-2-76-adenoma-T-0003.roi
# 207-1-27-adenoma-T-0001.roi
# 117-2-69-adenoma-S-0003.roi
# 317-1-58-adenoma-T-0001.jpg
# 520-2-59-adenoma-T-0001.roi
# 547-1-64-adenoma-A-0001.roi
# 469-2-59-adenoma-S-0001.jpg
# 406-1-74-adenoma-T-0002.jpg
# 492-1-55-polyp-S-0001.roi
# 484-1-80-adenoma-S-0003.roi
# 280-2-46-adenoma-A-0001.roi
# 115-1-78-polyp-R-0008.roi
# 105-1-42-adenoma-S-0002.jpg
# 408-1-53-adenoma-A-0001.jpg
# 159-2-73-adenoma-A-0000.jpg
# 487-1-63-adenoma-A-0001.jpg
# 213-2-53-adenoma-T-0001.jpg
# 385-1-72-polyp-S-0001.jpg
# 299-1-65-adenoma-S-0005.jpg
# 096-1-76-adenoma-A-0000.jpg
# 214-1-77-adenoma-A-0001.roi
# 009-2-67-adenoma-T-0000.jpg
# 476-1-41-adenoma-C-0001.roi
# 521-2-60-adenoma-S-0001.jpg
# 312-1-54-adenoma-S-0001.jpg
# 014-1-47-adenoma-T-0000.jpg
# 528-1-82-adenoma-D-0001.roi
# 290-1-54-adenoma-A-0002.roi
# 110-1-66-adenoma-A-0000.jpg
# 090-1-62-adenoma-S-0000.jpg
# 215-1-77-adenoma-D-0002.jpg
# 137-1-42-adenoma-S-0000.roi
# 459-1-70-adenoma-D-0005.jpg
# 505-2-51-polyp-RS-0002.jpg
# 480-2-62-adenoma-RS-0001.roi
# 054-2-58-adenoma-S-0000.jpg
# 260-2-77-adenoma-S-0002.jpg
# 442-1-61-adenoma-T-0003.roi
# 050-2-76-adenoma-S-0000.jpg
# 428-1-54-adenoma-S-0003.jpg
# 427-1-54-adenoma-S-0002.jpg
# 452-2-76-adenoma-S-0005.roi
# 441-1-61-adenoma-T-0002.jpg
# 048-1-57-adenoma-R-0000.roi
# 348-1-78-adenoma-T-0006.roi
# 066-2-66-adenoma-T-0000.jpg
# 362-2-77-adenoma-R-0003.jpg
# 330-1-62-adenoma-A-0001.jpg
# 456-2-76-adenoma-T-0004.jpg
# 036-1-74-adenoma-T-0000.jpg
# 126-1-63-adenoma-T-0000.jpg
# 155-2-68-adenoma-R-0002.roi
# 140-2-64-adenoma-S-0001.roi
# 255-2-61-adenoma-S-0000.roi
# 133-1-60-polyp-30cm-0000.roi
# 433-1-52-adenoma-T-0001.roi
# 387-1-77-adenoma-D-0002.roi
# 085-2-71-adenoma-S-0010.roi
# 524-1-71-adenoma-D-0003.roi
# 451-2-76-adenoma-S-0001.jpg
# 259-2-77-adenoma-S-0001.roi
# 208-1-27-polyp-T-0003.jpg
# 057-1-74-adenoma-R-0000.jpg
# 194-2-54-adenoma-A-0001.roi
# 494-1-78-2-adenoma-RS-0001.jpg
# 445-2-84-adenoma-D-0003.roi
# 371-1-56-adenoma-A-0001.jpg
# 380-1-48-adenoma-S-0002.roi
# 375-1-63-adenoma-A-0001.roi
# 211-1-70-adenoma-S-0001.jpg
# 334-1-72-adenoma-T-0001.jpg
# 384-2-59-adenoma-HF-0001.roi
# 269-1-62-adenoma-A-0001.roi
# 350-1-55-adenoma-T-0002.roi
# 457-1-70-adenoma-A-0001.roi
# 024-1-80-adenoma-T-0000.roi
# 157-2-54-adenoma-A-0000.jpg
# 072-2-59-adenoma-C-0000.jpg
# 017-1-59-adenoma-S-0000.jpg
# 199-2-58-adenoma-S-0001.jpg
# 359-2-77-adenoma-D-0001.jpg
# 543-1-82-adenoma-A-0001.roi
# 022-2-80-adenoma-A-0000.jpg
# 333-2-73-adenoma-S-0001.roi
# 355-1-69-adenoma-T-0001.jpg
# 116-2-69-adenoma-D-0001.roi
# 365-2-72-adenoma-S-0002.jpg
# 226-2-72-adenoma-D-0000.jpg
# 301-1-81-adenoma-S-0001.jpg
# 234-1-49-polyp-S-0000.jpg
# 410-1-55-adenoma-A-0001.roi
# 279-1-49-polyp-D-0003.roi
# 060-1-52-adenoma-D-0000.jpg
# 166-1-56-polyp-T-0003.roi
# 257-2-45-adenoma-S-0002.jpg
# 382-1-73-adenoma-AV50-0001.roi
# 087-1-72-adenoma-T-0001.roi
# 025-1-61-adenoma-HF-0000.roi
# 229-2-61-polyp-A-0000.jpg
# 022-2-80-adenoma-A-0000.roi
# 482-1-71-adenoma-A-0001.jpg
# 234-1-49-polyp-S-0000.roi
# 410-1-55-adenoma-A-0001.jpg
# 301-1-81-adenoma-S-0001.roi
# 535-1-65-adenoma-D-0001.roi
# 060-1-52-adenoma-D-0000.roi
# 034-1-56-adenoma-R-0001.jpg
# 025-1-61-adenoma-HF-0000.jpg
# 382-1-73-adenoma-AV50-0001.jpg
# 257-2-45-adenoma-S-0002.roi
# 488-1-63-adenoma-T-0002.roi
# 296-1-65-adenoma-R-0002.roi
# 124-1-68-polyp-A-0004.jpg
# 277-1-49-polyp-D-0001.roi
# 040-1-54-polyp-T-0001.jpg
# 123-1-61-adenoma-A-0000.jpg
# 251-1-57-adenoma-D-0001.roi
# 157-2-54-adenoma-A-0000.roi
# 199-2-58-adenoma-S-0001.roi
# 072-2-59-adenoma-C-0000.roi
# 548-1-64-adenoma-A-0004.jpg
# 322-1-54-adenoma-D-0002.roi
# 208-1-27-polyp-T-0003.roi
# 259-2-77-adenoma-S-0001.jpg
# 071-1-62-adenoma-S-0004.jpg
# 194-2-54-adenoma-A-0001.jpg
# 057-1-74-adenoma-R-0000.roi
# 094-1-64-adenoma-T-0000.roi
# 375-1-63-adenoma-A-0001.jpg
# 380-1-48-adenoma-S-0002.jpg
# 447-2-47-adenoma-S-0001.jpg
# 494-1-78-2-adenoma-RS-0001.roi
# 211-1-70-adenoma-S-0001.roi
# 150-2-62-adenoma-R-0002.jpg
# 066-2-66-adenoma-T-0000.roi
# 348-1-78-adenoma-T-0006.jpg
# 126-1-63-adenoma-T-0000.roi
# 098-1-76-polyp-D-0004.jpg
# 023-1-62-adenoma-D-0000.jpg
# 120-1-69-adenoma-T-0000.jpg
# 255-2-61-adenoma-S-0000.jpg
# 477-1-41-adenoma-T-0002.jpg
# 238-2-82-adenoma-A-0000.jpg
# 361-2-77-adenoma-R-0002.jpg
# 491-1-63-polyp-S-0006.roi
# 433-1-52-adenoma-T-0001.jpg
# 338-2-75-adenoma-T-0002.jpg
# 442-1-61-adenoma-T-0003.jpg
# 468-1-52-adenoma-T-0001.roi
# 176-2-77-adenoma-A-0002.jpg
# 541-2-52-adenoma-S-0002.roi
# 549-1-68-adenoma-S-0001.jpg
# 523-2-84-adenoma-R-0001.roi
# 198-1-67-adenoma-D-0001.jpg
# 247-1-61-adenoma-A-0003.roi
# 441-1-61-adenoma-T-0002.roi
# 472-1-65-adenoma-T-0001.jpg
# 184-2-71-adenoma-A-0000.jpg
# 466-2-55-adenoma-C-0001.roi
# 214-1-77-adenoma-A-0001.jpg
# 366-1-75-adenoma-S-0002.jpg
# 476-1-41-adenoma-C-0001.jpg
# 227-2-72-adenoma-S-0001.roi
# 459-1-70-adenoma-D-0005.roi
# 090-1-62-adenoma-S-0000.roi
# 215-1-77-adenoma-D-0002.roi
# 394-2-77-adenoma-S-0003.jpg
# 547-1-64-adenoma-A-0001.jpg
# 190-1-60-adenoma-A-0000.jpg
# 329-2-64-adenoma-A-0003.jpg
# 076-2-56-adenoma-A-0001.jpg
# 316-1-72-polyp-SF-0001.jpg
# 318-1-66-adenoma-A-0001.roi
# 484-1-80-adenoma-S-0003.jpg
# 504-2-51-polyp-RS-0001.jpg
# 487-1-63-adenoma-A-0001.roi
# 158-1-56-adenoma-20cm-0000.roi
# 159-2-73-adenoma-A-0000.roi
# 105-1-42-adenoma-S-0002.roi
# 275-1-52-adenoma-T-0001.jpg
# 055-1-75-adenoma-S-0001.roi
# 139-2-64-adenoma-R-0000.roi
# 135-1-70-adenoma-T-0001.roi
# 439-1-51-polyp-0001.jpg
# 056-1-75-adenoma-T-0002.roi
# 107-1-83-adenoma-A-0001.roi
# 336-2-62-adenoma-A-0001.jpg
# 222-1-71-adenoma-A-0004.jpg
# 324-2-53-adenoma-T-0001.roi
# 114-1-78-polyp-R-0007.roi
# 407-1-61-adenoma-C-0001.jpg
# 455-2-76-adenoma-T-0003.jpg
# 283-2-70-adenoma-A-0002.jpg
# ../Data/Split_Data/train/abnormal
# Processing directory: ../Data/Split_Data/train/abnormal
# 376-1-50-1-T.jpg
# 246-1-58-1-S.jpg
# 038-2-76-1-T.jpg
# 336-2-45-1-A.jpg
# 385-2-69-1-A.jpg
# 132-2-74-1-R.jpg
# 247-1-58-1-T.jpg
# 387-2-69-1-HF.jpg
# 503-2-50-1-A.jpg
# 239-2-52-1-R.jpg
# 515-2-55-1-D.jpg
# 341-2-72-1-C.jpg
# 396-2-53-1-HF.jpg
# 066-1-63-1-HF.jpg
# 188-1-53-1-C.jpg
# 514-2-55-1-C.jpg
# 091-1-67-1-A.jpg
# 145-1-74-1-HF.jpg
# 162-1-80-1-D.jpg
# 193-2-66-1-A.jpg
# 069-1-51-1-C.jpg
# 348-1-55-1-HF.jpg
# 425-1-49-1-R.jpg
# 510-1-45-1-R.jpg
# 100-1-49-1-HF.jpg
# 189-1-53-1-D.jpg
# 282-2-78-1-C.jpg
# 390-2-69-1-T.jpg
# 077-1-53-1-R.jpg
# 505-2-50-1-R.jpg
# 394-1-34-1-S.jpg
# 094-2-58-1-C.jpg
# 513-2-55-1-A.jpg
# 484-1-53-1-D.jpg
# 289-1-50-1-S.jpg
# 283-2-78-1-D.jpg
# 046-1-28-1-D.jpg
# 502-2-48-1-T.jpg
# 008-1-62-1-T.jpg
# 095-2-58-1-D.jpg
# 498-2-48-1-HF.jpg
# 499-2-48-1-R.jpg
# 284-2-78-1-R.jpg
# 015-2-71-1-R.jpg
# 345-1-55-1-A.jpg
# 328-2-79-1-T.jpg
# 219-2-69-1-R.jpg
# 208-1-61-1-S.jpg
# 224-2-75-1-HF.jpg
# 202-1-55-1-D.jpg
# 331-2-55-1-C.jpg
# 212-1-66-1-R.jpg
# 393-1-34-1-R.jpg
# 356-2-67-1-T.jpg
# 229-2-56-1-A.jpg
# 011-1-79-1-R.jpg
# 442-2-76-1-T.jpg
# 371-1-50-1-A.jpg
# 146-1-74-1-R.jpg
# 062-2-60-1-D.jpg
# 251-1-72-1-S.jpg
# 087-1-55-1-A.jpg
# 165-1-80-1-T.jpg
# 106-2-61-1-T.jpg
# 322-2-63-1-T.jpg
# 097-2-45-1-R.jpg
# 311-2-33-1-S.jpg
# 350-1-55-1-S.jpg
# 006-1-62-1-HF.jpg
# 164-1-80-1-S.jpg
# 028-2-55-1-SF.jpg
# 257-1-54-1-R.jpg
# 047-1-28-1-HF.jpg
# 351-1-55-1-T.jpg
# 395-2-53-1-D.jpg
# 253-2-73-1-R.jpg
# 163-1-80-1-R.jpg
# 511-1-45-1-S.jpg
# 399-2-40-1-D.jpg
# 459-1-30-1-A.jpg
# 468-1-52-1-T.jpg
# 158-1-51-1-T.jpg
# 488-2-62-1-D.jpg
# 448-1-69-1-T.jpg
# 435-2-58-1-D.jpg
# 409-1-56-1-HF.jpg
# 201-1-82-1-R.jpg
# 276-1-58-1-S.jpg
# 127-1-69-1-D.jpg
# 392-1-34-1-HF.jpg
# 167-2-38-1-D.jpg
# 430-1-57-1-HF.jpg
# 485-1-53-1-R.jpg
# 277-1-58-1-T.jpg
# 107-2-84-1-T.jpg
# 116-2-74-1-T.jpg
# 366-1-55-1-S.jpg
# 449-2-75-1-R.jpg
# 147-1-74-1-S.jpg
# 018-2-55-1-T.jpg
# 250-1-72-1-R.jpg
# 367-1-55-1-T.jpg
# 194-2-66-1-D.jpg
# 265-2-73-1-D.jpg
# 060-2-64-1-R.jpg
# 340-2-72-1-A.jpg
# 382-2-56-1-S.jpg
# 130-1-65-1-R.jpg
# 228-1-66-1-HF.jpg
# 483-1-53-1-C.jpg
# 003-1-70-1-A.jpg
# 203-1-55-1-R.jpg
# 317-1-57-1-R.jpg
# 022-1-58-1-C.jpg
# 198-2-66-1-T.jpg
# 070-2-62-1-A.jpg
# 306-1-56-1-SF.jpg
# 291-1-59-1-A.jpg
# 388-2-69-1-R.jpg
# 123-1-59-1-R.jpg
# 161-2-49-1-R.jpg
# 174-2-76-1-R.jpg
# 055-2-55-1-T.jpg
# 023-1-58-1-R.jpg
# 452-1-52-1-S.jpg
# 308-2-33-1-A.jpg
# 299-1-70-1-S.jpg
# 324-2-79-1-C.jpg
# 444-1-69-1-D.jpg
# 304-1-56-1-HF.jpg
# 048-1-35-1-A.jpg
# 086-1-57-1-T.jpg
# 173-2-76-1-D.jpg
# 453-1-52-1-T.jpg
# 279-1-54-1-R.jpg
# 067-1-63-1-R.jpg
# 325-2-79-1-D.jpg
# 309-2-33-1-D.jpg
# 428-1-51-1-R.jpg
# 141-2-62-1-D.jpg
# 490-2-62-1-R.jpg
# 053-1-58-1-T.jpg
# 155-1-51-1-C.jpg
# 140-2-62-1-C.jpg
# 323-2-79-1-A.jpg
# 020-2-59-1-R.jpg
# 302-1-56-1-C.jpg
# 190-1-53-1-R.jpg
# 278-1-54-1-A.jpg
# 049-1-35-1-R.jpg
# 206-1-61-1-HF.jpg
# 111-2-59-1-T.jpg
# 303-1-56-1-D.jpg
# 415-1-64-1-D.jpg
# 319-2-63-1-A.jpg
# 058-2-69-1-HF.jpg
# 489-2-62-1-HF.jpg
# 261-2-52-1-C.jpg
# 438-2-76-1-C.jpg
# 110-2-59-1-D.jpg
# 154-1-51-1-A.jpg
# 464-1-52-1-A.jpg
# 433-1-57-1-T.jpg
# 477-1-29-1-D.jpg
# 124-1-59-1-T.jpg
# 267-1-71-1-A.jpg
# 410-1-56-1-R.jpg
# 032-1-54-1-R.jpg
# 359-1-68-1-HF.jpg
# 432-1-57-1-S.jpg
# 316-1-57-1-D.jpg
# 389-2-69-1-S.jpg
# 478-1-29-1-HF.jpg
# 238-2-52-1-HF.jpg
# 122-1-59-1-D.jpg
# 175-2-76-1-S.jpg
# 160-2-49-1-D.jpg
# 151-1-51-1-HF.jpg
# 027-2-55-1-HF.jpg
# 260-2-52-1-A.jpg
# 476-1-53-1-S.jpg
# 005-1-62-1-C.jpg
# 249-1-72-1-D.jpg
# 025-2-55-1-C.jpg
# 360-1-68-1-R.jpg
# 040-1-58-1-HF.jpg
# 518-2-55-1-S.jpg
# 108-1-78-1-A.jpg
# 458-2-54-1-S.jpg
# 349-1-55-1-R.jpg
# 076-2-62-1-T.jpg
# 491-2-62-1-S.jpg
# 377-2-56-1-A.jpg
# 101-1-49-1-S.jpg
# 434-1-34-1-R.jpg
# 248-1-72-1-A.jpg
# 152-1-51-1-R.jpg
# 180-2-64-1-R.jpg
# 204-1-61-1-A.jpg
# 463-1-30-1-T.jpg
# 465-1-52-1-D.jpg
# 178-2-64-1-D.jpg
# 021-2-59-1-S.jpg
# 054-2-55-1-A.jpg
# 153-1-51-1-T.jpg
# 235-1-56-1-S.jpg
# 191-1-53-1-S.jpg
# 411-1-56-1-SF.jpg
# 462-1-30-1-S.jpg
# 443-1-69-1-A.jpg
# 339-2-45-1-T.jpg
# 169-2-38-1-S.jpg
# 447-1-69-1-S.jpg
# 487-2-62-1-A.jpg
# 241-2-52-1-T.jpg
# 176-2-76-1-T.jpg
# 121-1-59-1-C.jpg
# 017-2-55-1-R.jpg
# 083-1-57-1-D.jpg
# 036-2-76-1-HF.jpg
# 129-1-69-1-S.jpg
# 240-2-52-1-S.jpg
# 368-2-82-1-D.jpg
# 419-1-64-1-SDJ.jpg
# 451-1-52-1-R.jpg
# 199-1-82-1-C.jpg
# 084-1-57-1-R.jpg
# 187-1-53-1-A.jpg
# 207-1-61-1-R.jpg
# 301-1-56-1-A.jpg
# 185-2-42-1-R.jpg
# 402-1-65-1-R.jpg
# 473-1-53-1-D.jpg
# 217-2-69-1-C.jpg
# 220-2-69-1-S.jpg
# 073-2-62-1-C.jpg
# 287-1-50-1-A.jpg
# 033-1-76-1-D.jpg
# 142-2-62-1-R.jpg
# 026-2-55-1-D.jpg
# 470-2-52-1-R.jpg
# 264-2-52-1-S.jpg
# 472-1-53-1-A.jpg
# 454-1-57-1-R.jpg
# 221-2-69-1-T.jpg
# 089-1-55-1-R.jpg
# 102-1-49-1-T.jpg
# 065-1-63-1-A.jpg
# 075-2-62-1-R.jpg
# 460-1-30-1-D.jpg
# 099-1-49-1-D.jpg
# 263-2-52-1-R.jpg
# 315-1-57-1-A.jpg
# 183-2-42-1-A.jpg
# 144-2-62-1-T.jpg
# 467-1-52-1-S.jpg
# 157-1-51-1-S.jpg
# 232-2-56-1-R.jpg
# 150-1-51-1-D.jpg
# 192-1-53-1-T.jpg
# 082-1-57-1-A.jpg
# 034-1-76-1-R.jpg
# 509-1-45-1-HF.jpg
# 314-2-31-1-S.jpg
# 128-1-69-1-R.jpg
# 355-2-67-1-SF.jpg
# 446-1-69-1-R.jpg
# 412-1-56-1-T.jpg
# 420-1-64-1-T.jpg
# 030-1-54-1-C.jpg
# 431-1-57-1-R.jpg
# 004-1-59-1-R.jpg
# 327-2-79-1-R.jpg
# 475-1-53-1-R.jpg
# 496-2-48-1-C.jpg
# 007-1-62-1-R.jpg
# 369-2-82-1-R.jpg
# 210-1-75-1-R.jpg
# 450-1-52-1-D.jpg
# 085-1-57-1-S.jpg
# 209-1-61-1-SDJ.jpg
# 497-2-48-1-D.jpg
# 119-1-60-1-R.jpg
# 313-2-31-1-R.jpg
# 096-2-58-1-HF.jpg
# 120-1-59-1-A.jpg
# 001-1-63-1-R.jpg
# 182-2-64-1-T.jpg
# 455-1-57-1-S.jpg
# 474-1-53-1-HF.jpg
# 259-1-54-1-T.jpg
# 143-2-62-1-S.jpg
# 471-2-52-1-S.jpg
# 258-1-54-1-S.jpg
# 233-2-56-1-S.jpg
# 156-1-51-1-R.jpg
# 236-2-52-1-C.jpg
# 135-1-58-1-D.jpg
# 337-2-45-1-HF.jpg
# 271-1-71-1-T.jpg
# 216-2-69-1-a.jpg
# 043-1-58-1-T.jpg
# 295-1-59-1-S.jpg
# 074-2-62-1-D.jpg
# 461-1-30-1-R.jpg
# 134-1-58-1-C.jpg
# 262-2-52-1-D.jpg
# 118-1-60-1-HF.jpg
# 270-1-71-1-S.jpg
# 037-2-76-1-R.jpg
# 138-1-58-1-S.jpg
# 397-2-53-1-R.jpg
# 213-1-73-1-D.jpg
# 400-2-40-1-S.jpg
# 312-2-33-1-T.jpg
# 321-2-63-1-S.jpg
# 362-1-55-1-A.jpg
# 456-2-54-1-D.jpg
# 374-1-50-1-R.jpg
# 104-2-61-1-C.jpg
# 215-1-73-1-T.jpg
# 131-2-74-1-D.jpg
# 056-2-69-1-A.jpg
# 427-1-49-1-T.jpg
# 512-1-45-1-T.jpg
# 177-2-64-1-C.jpg
# 373-1-50-1-D.jpg
# 346-1-55-1-C.jpg
# 445-1-69-1-HF.jpg
# 243-1-58-1-C.jpg
# 159-2-49-1-C.jpg
# 268-1-71-1-D.jpg
# 024-1-58-1-SDJ.jpg
# 255-1-54-1-D.jpg
# 372-1-50-1-C.jpg
# 343-2-72-1-R.jpg
# 080-2-55-1-R.jpg
# 039-1-58-1-D.jpg
# 358-1-68-1-D.jpg
# 136-1-58-1-HF.jpg
# 297-1-70-1-C.jpg
# 364-1-55-1-HF.jpg
# 196-2-66-1-R.jpg
# 354-2-67-1-S.jpg
# 179-2-64-1-HF.jpg
# 274-1-58-1-D.jpg
# 254-1-54-1-A.jpg
# 334-2-55-1-S.jpg
# 437-2-58-1-S.jpg
# 326-2-79-1-HF.jpg
# 071-1-78-1-C.jpg
# 440-2-76-1-R.jpg
# 013-1-79-1-T.jpg
# 016-2-71-1-S.jpg
# 479-1-29-1-R.jpg
# 333-2-55-1-R.jpg
# 429-1-57-1-D.jpg
# 115-2-74-1-R.jpg
# 093-1-67-1-S.jpg
# 406-2-69-1-HF.jpg
# 501-2-48-1-SF.jpg
# 148-1-51-1-A.jpg
# 500-2-48-1-S.jpg
# 363-1-55-1-D.jpg
# 507-1-45-1-A.jpg
# 286-2-78-1-T.jpg
# 211-1-66-1-D.jpg
# 517-2-55-1-R.jpg
# 200-1-82-1-HF.jpg
# 227-1-59-1-T.jpg
# 051-2-60-1-S.jpg
# 293-1-59-1-HF.jpg
# 050-1-64-1-R.jpg
# 457-2-54-1-R.jpg
# 342-2-72-1-HF.jpg
# 300-1-72-1-R.jpg
# 112-2-74-1-A.jpg
# 244-1-58-1-D.jpg
# 009-1-77-1-R.jpg
# 269-1-71-1-R.jpg
# 149-1-51-1-C.jpg
# 416-1-64-1-HF.jpg
# 090-1-55-1-T.jpg
# 344-2-72-1-T.jpg
# 266-2-73-1-S.jpg
# 063-1-68-1-R.jpg
# 520-2-55-1-T.jpg
# 068-1-63-1-T.jpg
# 275-1-58-1-R.jpg
# 436-2-58-1-R.jpg
# 057-2-69-1-C.jpg
# 088-1-55-1-HF.jpg
# 379-2-56-1-D.jpg
# 391-1-34-1-D.jpg
# 170-2-38-1-T.jpg
# 378-2-56-1-C.jpg
# 031-1-54-1-HF.jpg
# 408-2-69-1-S.jpg
# 386-2-69-1-D.jpg
# 310-2-33-1-HF.jpg
# 506-2-50-1-T.jpg
# 252-1-72-1-T.jpg
# 064-1-68-1-S.jpg
# 231-2-56-1-HF.jpg
# 113-2-74-1-D.jpg
# 441-2-76-1-S.jpg
# 242-1-58-1-A.jpg
# 421-1-49-1-A.jpg
# 318-1-57-1-T.jpg
# 332-2-55-1-D.jpg
# ../Data/Split_Data/test/normal
# Processing directory: ../Data/Split_Data/test/normal
# 297-1-65-adenoma-R-0003.jpg
# 305-1-50-adenoma-T-0003.roi
# 109-1-83-adenoma-T-0003.jpg
# 335-1-72-adenoma-T-0002.jpg
# 267-2-75-adenoma-S-0001.jpg
# 119-2-64-adenoma-20cm-0000.jpg
# 289-1-54-adenoma-A-0001.roi
# 274-2-74-adenoma-AV15-0003.roi
# 306-1-67-adenoma-RS-0002.jpg
# 420-2-67-adenoma-A-0001.jpg
# 341-2-44-adenoma-A-0001.roi
# 351-1-55-adenoma-T-0003.roi
# 254-2-50-polyp-R-0002.roi
# 145-1-60-polyp-D-0002.jpg
# 128-2-55-polyp-A-0000.roi
# 121-1-63-adenoma-D-0000.jpg
# 516-1-74-adenoma-R-0002.roi
# 223-1-71-adenoma-S-0005.jpg
# 209-2-75-adenoma-T-0001.jpg
# 509-1-61-adenoma-A-0001.jpg
# 003-1-63-adenoma-S-0000.roi
# 181-1-50-adenoma-S-0000.roi
# 185-2-61-adenoma-T-0000.roi
# 443-1-59-adenoma-R-0001.roi
# 171-1-57-adenoma-A-0000.jpg
# 047-1-76-adenoma-RS-0001.jpg
# 294-1-65-adenoma-R-0003.roi
# 339-2-41-adenoma-D-0001.jpg
# 326-2-66-adenoma-T-0002.jpg
# 216-1-77-adenoma-S-0003.roi
# 059-1-37-adenoma-S-0000.jpg
# 285-2-66-adenoma-A-0001.roi
# 011-2-48-adenoma-S-0000.jpg
# 103-1-42-adenoma-S-0000.roi
# 240-2-82-adenoma-T-0003.jpg
# 165-1-56-adenoma-D-0000.roi
# 411-1-55-adenoma-R-0005.jpg
# 141-2-64-adenoma-T-0002.jpg
# 256-2-45-adenoma-S-0001.jpg
# 271-1-62-polyp-R-0002.jpg
# 106-2-56-adenoma-C-0002.jpg
# 550-1-75-adenoma-R-0001.roi
# 291-1-54-adenoma-S-0003.jpg
# 512-1-50-polyp-R-0003.roi
# 179-2-77-polyp-R-0005.jpg
# 068-1-53-polyp-S-0000.jpg
# 369-1-61-adenoma-A-0001.jpg
# 368-1-70-adenoma-S-0002.jpg
# 028-1-59-polyp-R-0000.roi
# 325-2-66-adenoma-T-0001.roi
# 266-2-51-adenoma-AV20-0001.roi
# 212-1-59-adenoma-S-0001.roi
# 370-1-61-adenoma-HF-0002.roi
# 041-1-74-adenoma-A-0000.roi
# 163-2-79-adenoma-T-0001.jpg
# 258-2-77-adenoma-S-0000.roi
# 019-1-59-adenoma-S-0002.jpg
# 321-1-54-adenoma-A-0001.jpg
# 147-2-68-adenoma-S-0000.roi
# 089-1-53-adenoma-25cm-0001.roi
# 052-1-67-adenoma-T-0001.roi
# 010-2-67-adenoma-T-0001.jpg
# 300-1-51-adenoma-T-0001.jpg
# 113-1-78-polyp-R-0006.roi
# 463-1-70-adenoma-T-0003.roi
# 015-1-65-polyp-S-0001.jpg
# 170-2-62-adenoma-S-0001.jpg
# 013-1-70-adenoma-A-0000.roi
# 531-1-58-adenoma-T-0002.roi
# 074-1-57-adenoma-A-0000.roi
# 485-1-80-adenoma-S-0004.roi
# 270-1-62-adenoma-S-0001.jpg
# 038-2-75-adenoma-A-0001.roi
# 174-1-61-polyp-S-0001.roi
# 134-1-70-adenoma-A-0000.jpg
# 210-1-70-adenoma-S-0000.jpg
# 104-1-42-adenoma-S-0001.jpg
# 298-1-65-adenoma-S-0004.jpg
# 101-1-76-polyp-S-0007.roi
# 320-1-66-adenoma-T-0003.roi
# 206-1-54-adenoma-HF-0000.jpg
# 364-2-72-adenoma-A-0001.roi
# 347-1-78-adenoma-AV30-0007.roi
# 153-2-50-adenoma-SF-0000.roi
# 432-1-51-adenoma-T-0001.roi
# 081-2-71-adenoma-D-0001.roi
# 178-2-77-adenoma-T-0004.roi
# 425-2-75-polyp-R-0003.jpg
# 077-2-56-adenoma-A-0002.roi
# 235-2-49-adenoma-R-0001.roi
# 080-2-73-polyp-T-0004.jpg
# 349-1-55-adenoma-T-0001.roi
# 281-2-66-adenoma-A-0001.roi
# 252-1-59-adenoma-A-0000.jpg
# 202-1-81-adenoma-T-0000.roi
# 148-1-59-adenoma-R-0000.jpg
# 327-2-64-adenoma-A-0001.roi
# 092-1-62-polyp-S-0000.roi
# 042-1-53-adenoma-C-0000.jpg
# 053-2-58-adenoma-D-0000.roi
# 250-1-60-adenoma-A-0001.roi
# 282-2-70-adenoma-A-0001.roi
# 396-1-68-adenoma-T-0002.jpg
# 168-1-54-polyp-T-0001.jpg
# 118-2-60-adenoma-HF-0000.roi
# 161-1-34-adenoma-S-0000.jpg
# 261-2-77-adenoma-S-0003.jpg
# 095-1-64-adenoma-T-0004.jpg
# 486-1-80-adenoma-T-0002.roi
# 183-1-59-adenoma-A-0000.roi
# 200-1-62-adenoma-C-0000.roi
# 177-2-77-adenoma-A-0003.roi
# 438-2-63-adenoma-C-0001.jpg
# 237-1-43-leiomyoma-S-0000.jpg
# 533-2-41-adenoma-D-0001.roi
# 268-1-54-adenoma-T-0001.jpg
# 248-1-78-adenoma-A-0000.jpg
# 352-1-75-adenoma-A-0001.jpg
# 539-1-70-adenoma-A-0001.roi
# 470-1-65-adenoma-S-0002.roi
# 162-1-34-adenoma-S-0001.roi
# 049-1-57-adenoma-S-0001.roi
# 246-1-61-adenoma-A-0002.jpg
# 440-1-61-adenoma-T-0001.jpg
# 273-2-74-adenoma-AV15-0002.roi
# 381-1-73-adenoma-AV40-0003.jpg
# 308-2-70-adenoma-A-0002.jpg
# 449-1-75-2-adenoma-0001.jpg
# 191-1-55-adenoma-T-0000.jpg
# 395-1-68-adenoma-T-0001.roi
# 405-1-74-adenoma-S-0008.roi
# 129-1-63-adenoma-C-0000.jpg
# 426-1-54-adenoma-S-0001.jpg
# 245-1-61-adenoma-A-0001.roi
# 131-1-58-leiomyoma-D-0002.roi
# 192-1-55-adenoma-T-0001.roi
# 374-1-68-adenoma-S-0002.roi
# 230-1-71-polyp-S-0001.roi
# 172-1-57-adenoma-S-0001.jpg
# 044-1-53-adenoma-T-0002.roi
# 522-2-42-adenoma-T-0001.roi
# 149-2-62-adenoma-R-0001.roi
# 403-1-74-adenoma-S-0006.roi
# 007-2-57-adenoma-S-0002.roi
# 399-2-62-adenoma-A-0001.jpg
# 448-1-71-adenoma-A-0001.roi
# 500-2-68-adenoma-D-0003.jpg
# 164-2-55-lipoma-A-0001.roi
# 373-1-68-adenoma-A-0001.roi
# 511-1-42-adenoma-T-0001.jpg
# 091-1-62-adenoma-T-0001.roi
# 272-2-74-adenoma-AV15-0001.jpg
# 419-1-60-adenoma-0001.roi
# 016-1-56-adenoma-D-0000.roi
# 154-2-68-adenoma-A-0001.jpg
# 357-2-73-adenoma-S-0001.jpg
# 501-2-47-adenoma-C-0001.jpg
# 002-1-43-adenoma-D-0000.roi
# 149-2-62-adenoma-R-0001.jpg
# 522-2-42-adenoma-T-0001.jpg
# 070-1-62-adenoma-S-0003.jpg
# 044-1-53-adenoma-T-0002.jpg
# 328-2-64-adenoma-A-0002.jpg
# 230-1-71-polyp-S-0001.jpg
# 374-1-68-adenoma-S-0002.jpg
# 500-2-68-adenoma-D-0003.roi
# 399-2-62-adenoma-A-0001.roi
# 419-1-60-adenoma-0001.jpg
# 373-1-68-adenoma-A-0001.jpg
# 218-1-48-adenoma-HF-0000.roi
# 195-2-54-adenoma-S-0003.roi
# 002-1-43-adenoma-D-0000.jpg
# 409-2-54-adenoma-T-0001.roi
# 501-2-47-adenoma-C-0001.roi
# 357-2-73-adenoma-S-0001.roi
# 493-2-70-adenoma-A-0001.jpg
# 154-2-68-adenoma-A-0001.roi
# 532-1-56-adenoma-T-0001.roi
# 288-1-60-polyp-T-0002.roi
# 449-1-75-2-adenoma-0001.roi
# 308-2-70-adenoma-A-0002.roi
# 203-2-48-polyp-R-0000.roi
# 273-2-74-adenoma-AV15-0002.jpg
# 381-1-73-adenoma-AV40-0003.roi
# 440-1-61-adenoma-T-0001.roi
# 453-2-76-adenoma-S-0006.jpg
# 160-1-56-adenoma-RSJ-0000.roi
# 405-1-74-adenoma-S-0008.jpg
# 033-2-63-adenoma-A-0000.roi
# 191-1-55-adenoma-T-0000.roi
# 196-2-44-adenoma-T-0000.roi
# 245-1-61-adenoma-A-0001.jpg
# 067-1-57-adenoma-S-0000.roi
# 020-1-59-adenoma-S-0003.jpg
# 309-2-40-polyp-A-0001.roi
# 192-1-55-adenoma-T-0001.jpg
# 180-2-44-polyp-S-0000.jpg
# 220-1-48-tumor-A-0002.roi
# 540-1-51-adenoma-D-0001.roi
# 118-2-60-adenoma-HF-0000.jpg
# 515-2-56-adenoma-A-0001.roi
# 168-1-54-polyp-T-0001.roi
# 396-1-68-adenoma-T-0002.roi
# 282-2-70-adenoma-A-0001.jpg
# 112-1-78-adenoma-S-0001.roi
# 095-1-64-adenoma-T-0004.roi
# 261-2-77-adenoma-S-0003.roi
# 437-1-56-adenoma-T-0001.jpg
# 345-1-78-adenoma-A-0004.roi
# 151-1-58-adenoma-T-0000.roi
# 237-1-43-leiomyoma-S-0000.roi
# 177-2-77-adenoma-A-0003.jpg
# 438-2-63-adenoma-C-0001.roi
# 446-2-84-adenoma-T-0002.jpg
# 064-1-64-adenoma-A-0000.roi
# 486-1-80-adenoma-T-0002.jpg
# 156-1-53-polyp-20cm-0001.roi
# 246-1-61-adenoma-A-0002.roi
# 346-1-78-adenoma-A-0005.jpg
# 152-1-58-adenoma-T-0001.jpg
# 470-1-65-adenoma-S-0002.jpg
# 417-1-57-adenoma-A-0003.jpg
# 088-2-76-polyp-A-0000.jpg
# 162-1-34-adenoma-S-0001.jpg
# 539-1-70-adenoma-A-0001.jpg
# 248-1-78-adenoma-A-0000.roi
# 352-1-75-adenoma-A-0001.roi
# 533-2-41-adenoma-D-0001.jpg
# 268-1-54-adenoma-T-0001.roi
# 029-1-80-adenoma-A-0000.roi
# 320-1-66-adenoma-T-0003.jpg
# 101-1-76-polyp-S-0007.jpg
# 086-1-72-adenoma-A-0000.jpg
# 475-1-52-adenoma-T-0002.roi
# 278-1-49-polyp-D-0002.jpg
# 298-1-65-adenoma-S-0004.roi
# 104-1-42-adenoma-S-0001.roi
# 178-2-77-adenoma-T-0004.jpg
# 153-2-50-adenoma-SF-0000.jpg
# 189-2-69-adenoma-S-0000.roi
# 364-2-72-adenoma-A-0001.jpg
# 412-1-55-adenoma-S-0003.jpg
# 281-2-66-adenoma-A-0001.jpg
# 349-1-55-adenoma-T-0001.jpg
# 080-2-73-polyp-T-0004.roi
# 413-1-55-adenoma-SF-0002.roi
# 293-1-65-adenoma-R-0002.roi
# 235-2-49-adenoma-R-0001.jpg
# 425-2-75-polyp-R-0003.roi
# 077-2-56-adenoma-A-0002.jpg
# 053-2-58-adenoma-D-0000.jpg
# 250-1-60-adenoma-A-0001.jpg
# 042-1-53-adenoma-C-0000.roi
# 092-1-62-polyp-S-0000.jpg
# 458-1-70-adenoma-D-0004.roi
# 465-1-51-polyp-A-0002.roi
# 327-2-64-adenoma-A-0001.jpg
# 321-1-54-adenoma-A-0001.roi
# 019-1-59-adenoma-S-0002.roi
# 258-2-77-adenoma-S-0000.jpg
# 163-2-79-adenoma-T-0001.roi
# 219-1-48-polyp-S-0001.jpg
# 186-1-80-adenoma-A-0000.roi
# 078-2-73-polyp-A-0002.jpg
# 323-2-50-polyp-A-0001.jpg
# 170-2-62-adenoma-S-0001.roi
# 013-1-70-adenoma-A-0000.jpg
# 300-1-51-adenoma-T-0001.roi
# 010-2-67-adenoma-T-0001.roi
# 052-1-67-adenoma-T-0001.jpg
# 089-1-53-adenoma-25cm-0001.jpg
# 270-1-62-adenoma-S-0001.roi
# 508-2-76-adenoma-AV20-0001.jpg
# 074-1-57-adenoma-A-0000.jpg
# 210-1-70-adenoma-S-0000.roi
# 051-1-67-adenoma-T-0000.roi
# 134-1-70-adenoma-A-0000.roi
# 264-2-50-adenoma-A-0001.jpg
# 550-1-75-adenoma-R-0001.jpg
# 035-1-56-adenoma-R-0002.jpg
# 538-2-66-2-adenoma-T-0001.roi
# 106-2-56-adenoma-C-0002.roi
# 141-2-64-adenoma-T-0002.roi
# 068-1-53-polyp-S-0000.roi
# 179-2-77-polyp-R-0005.roi
# 127-1-63-adenoma-T-0001.roi
# 368-1-70-adenoma-S-0002.roi
# 483-1-71-adenoma-A-0002.jpg
# 108-1-83-adenoma-D-0004.jpg
# 005-2-54-polyp-A-0000.roi
# 204-2-52-adenoma-A-0000.jpg
# 370-1-61-adenoma-HF-0002.jpg
# 266-2-51-adenoma-AV20-0001.jpg
# 212-1-59-adenoma-S-0001.jpg
# 392-2-77-adenoma-S-0001.roi
# 028-1-59-polyp-R-0000.jpg
# 171-1-57-adenoma-A-0000.roi
# 003-1-63-adenoma-S-0000.jpg
# 027-1-79-adenoma-T-0000.jpg
# 287-1-60-adenoma-A-0001.jpg
# 402-1-74-adenoma-D-0005.jpg
# 294-1-65-adenoma-R-0003.jpg
# 188-2-78-adenoma-35cm-0000.roi
# 527-1-54-adenoma-S-0001.jpg
# 311-1-58-adenoma-S-0001.roi
# 059-1-37-adenoma-S-0000.roi
# 429-1-54-adenoma-S-0004.roi
# 331-1-62-adenoma-A-0002.roi
# 537-1-63-adenoma-C-0002.jpg
# 165-1-56-adenoma-D-0000.jpg
# 240-2-82-adenoma-T-0003.roi
# 314-1-72-adenoma-S-0003.roi
# 496-2-84-adenoma-A-0002.roi
# 285-2-66-adenoma-A-0001.jpg
# 011-2-48-adenoma-S-0000.roi
# 342-1-58-polyp-R-0001.roi
# 292-1-65-adenoma-C-0001.jpg
# 097-1-76-adenoma-T-0001.roi
# 289-1-54-adenoma-A-0001.jpg
# 267-2-75-adenoma-S-0001.roi
# 119-2-64-adenoma-20cm-0000.roi
# 305-1-50-adenoma-T-0003.jpg
# 351-1-55-adenoma-T-0003.jpg
# 420-2-67-adenoma-A-0001.roi
# 037-1-74-adenoma-T-0002.roi
# 274-2-74-adenoma-AV15-0003.jpg
# 125-1-68-polyp-T-0005.jpg
# 284-2-77-adenoma-HF-0001.jpg
# 102-1-76-polyp-S-0008.roi
# 223-1-71-adenoma-S-0005.roi
# 516-1-74-adenoma-R-0002.jpg
# 272-2-74-adenoma-AV15-0001.jpg.zip
# 400-2-62-adenoma-A-0002.jpg
# 303-1-50-adenoma-T-0001.jpg
# 473-2-70-adenoma-A-0001.jpg
# 439-1-51-polyp-0001.roi
# 055-1-75-adenoma-S-0001.jpg
# 243-1-49-tumor-S-0002.roi
# 525-1-71-adenoma-T-0001.jpg
# 114-1-78-polyp-R-0007.jpg
# 510-2-60-adenoma-T-0001.roi
# 222-1-71-adenoma-A-0004.roi
# 336-2-62-adenoma-A-0001.roi
# 517-1-71-adenoma-T-0001.roi
# 415-1-57-adenoma-A-0001.jpg
# 489-1-63-polyp-S-0003.roi
# 360-2-77-adenoma-D-0002.roi
# 197-1-67-adenoma-C-0000.jpg
# 217-1-77-adenoma-T-0004.jpg
# 283-2-70-adenoma-A-0002.roi
# 175-2-77-adenoma-A-0001.jpg
# 173-1-61-polyp-S-0000.jpg
# 031-1-74-polyp-H-0001.jpg
# 407-1-61-adenoma-C-0001.roi
# 329-2-64-adenoma-A-0003.roi
# 061-1-52-adenoma-T-0001.roi
# 190-1-60-adenoma-A-0000.roi
# 507-2-51-polyp-RS-0004.roi
# 076-2-56-adenoma-A-0001.roi
# 544-1-82-adenoma-HF-0004.roi
# 504-2-51-polyp-RS-0001.roi
# 318-1-66-adenoma-A-0001.jpg
# 253-2-50-adenoma-A-0001.jpg
# 021-1-72-adenoma-S-0001.jpg
# 316-1-72-polyp-SF-0001.roi
# 275-1-52-adenoma-T-0001.roi
# 144-1-60-adenoma-T-0001.jpg
# 497-2-47-polyp-T-0001.roi
# 262-1-79-adenoma-A-0001.jpg
# 143-1-60-adenoma-A-0000.roi
# 315-1-72-polyp-R-0006.jpg
# 495-2-56-adenoma-S-0001.jpg
# 158-1-56-adenoma-20cm-0000.jpg
# 397-2-71-adenoma-S-0001.roi
# 472-1-65-adenoma-T-0001.roi
# 398-2-71-adenoma-S-0002.roi
# 004-1-57-polyp-D-0001.jpg
# 414-1-58-adenoma-A-0001.roi
# 366-1-75-adenoma-S-0002.roi
# 233-2-71-adenoma-S-0001.roi
# 343-1-58-adenoma-A-0001.roi
# 466-2-55-adenoma-C-0001.jpg
# 169-2-62-adenoma-R-0000.jpg
# 045-1-76-adenoma-R-0005.roi
# 184-2-71-adenoma-A-0000.roi
# 435-1-68-adenoma-A-0001.jpg
# 006-2-57-adenoma-S-0001.roi
# 227-2-72-adenoma-S-0001.jpg
# 276-1-52-adenoma-T-0002.jpg
# 063-1-59-polyp-S-0001.roi
# 394-2-77-adenoma-S-0003.roi
# 434-1-64-adenoma-T-0001.roi
# 526-1-71-adenoma-T-0002.roi
# 205-2-52-adenoma-T-0002.roi
# 307-2-81-adenoma-S-0001.roi
# 518-1-47-adenoma-T-0001.jpg
# 499-2-68-adenoma-A-0001.jpg
# 354-1-75-adenoma-S-0003.jpg
# 338-2-75-adenoma-T-0002.roi
# 530-1-58-adenoma-A-0001.roi
# 201-1-62-adenoma-C-0001.roi
# 468-1-52-adenoma-T-0001.jpg
# 176-2-77-adenoma-A-0002.roi
# 247-1-61-adenoma-A-0003.jpg
# 265-2-50-adenoma-T-0002.roi
# 416-1-57-adenoma-A-0002.roi
# 471-1-65-adenoma-S-0003.roi
# 198-1-67-adenoma-D-0001.roi
# 542-2-52-adenoma-T-0001.jpg
# 436-1-56-adenoma-R-0002.jpg
# 523-2-84-adenoma-R-0001.jpg
# 084-2-71-adenoma-S-0009.jpg
# 138-1-54-adenoma-S-0000.jpg
# 228-2-72-adenoma-T-0003.roi
# 541-2-52-adenoma-S-0002.jpg
# 549-1-68-adenoma-S-0001.roi
# 224-2-57-adenoma-SDJ-0001.roi
# 075-1-58-adenoma-D-0000.roi
# 474-1-52-adenoma-A-0001.jpg
# 378-1-59-adenoma-S-0001.roi
# 069-1-62-adenoma-S-0001.roi
# 506-2-51-polyp-RS-0003.jpg
# 302-1-81-adenoma-S-0002.roi
# 120-1-69-adenoma-T-0000.roi
# 001-1-54-adenoma-D-0000.jpg
# 023-1-62-adenoma-D-0000.roi
# 386-1-77-adenoma-A-0001.jpg
# 464-1-51-polyp-A-0001.jpg
# 546-1-83-adenoma-T-0005.jpg
# 310-2-40-polyp-A-0002.roi
# 098-1-76-polyp-D-0004.roi
# 344-1-78-adenoma-A-0001.jpg
# 361-2-77-adenoma-R-0002.roi
# 238-2-82-adenoma-A-0000.roi
# 073-2-47-adenoma-T-0000.jpg
# 460-1-70-adenoma-D-0006.roi
# 477-1-41-adenoma-T-0002.roi
# 391-1-58-polyp-S-0001.jpg
# 450-1-75-2-adenoma-0002.jpg
# 058-2-50-adenoma-R-0001.jpg
# 491-1-63-polyp-S-0006.jpg
# 012-2-57-adenoma-S-0000.jpg
# 514-1-59-adenoma-S-0002.jpg
# 444-2-84-adenoma-A-0001.jpg
# 545-1-83-adenoma-A-0002.roi
# 187-1-80-adenoma-A-0001.jpg
# 082-2-71-adenoma-S-0003.jpg
# 322-1-54-adenoma-D-0002.jpg
# 462-1-70-adenoma-T-0002.roi
# 094-1-64-adenoma-T-0000.jpg
# 132-1-61-polyp-D-0000.jpg
# 534-1-60-adenoma-S-0001.roi
# 295-1-65-adenoma-R-0001.roi
# 421-2-67-adenoma-A-0002.jpg
# 065-1-52-adenoma-T-0000.roi
# 447-2-47-adenoma-S-0001.roi
# 150-2-62-adenoma-R-0002.roi
# 503-1-35-polyp-A-0001.roi
# 358-1-65-adenoma-A-0002.jpg
# 479-2-49-polyp-0001.jpg
# 277-1-49-polyp-D-0001.jpg
# 388-1-68-adenoma-A-0001.roi
# 124-1-68-polyp-A-0004.roi
# 304-1-50-adenoma-T-0002.roi
# 296-1-65-adenoma-R-0002.jpg
# 083-2-71-adenoma-S-0008.roi
# 111-1-78-adenoma-D-0000.roi
# 251-1-57-adenoma-D-0001.jpg
# 123-1-61-adenoma-A-0000.roi
# 519-2-72-adenoma-T-0001.roi
# 383-1-73-adenoma-AV50-0002.jpg
# 032-2-55-adenoma-T-0000.roi
# 372-2-51-adenoma-S-0001.jpg
# 040-1-54-polyp-T-0001.roi
# 376-1-60-adenoma-T-0001.jpg
# 377-2-67-adenoma-C-0001.jpg
# 423-1-59-adenoma-S-0002.jpg
# 353-1-75-adenoma-S-0002.roi
# 548-1-64-adenoma-A-0004.roi
# 182-1-65-adenoma-D-0000.roi
# 018-1-59-adenoma-S-0001.jpg
# 241-1-65-adenoma-A-0000.roi
# 393-2-77-adenoma-S-0002.jpg
# 390-1-68-adenoma-T-0003.roi
# 229-2-61-polyp-A-0000.roi
# 467-2-55-adenoma-R-0002.roi
# 100-1-76-polyp-S-0006.roi
# 482-1-71-adenoma-A-0001.roi
# 130-1-63-adenoma-C-0001.jpg
# 535-1-65-adenoma-D-0001.jpg
# 232-2-71-adenoma-D-0000.roi
# 236-1-64-adenoma-A-0000.roi
# 093-1-62-polyp-S-0001.roi
# 286-2-66-adenoma-D-0002.roi
# 481-1-72-adenoma-S-0001.roi
# 431-1-73-polyp-S-0002.jpg
# 488-1-63-adenoma-T-0002.jpg
# 313-1-72-adenoma-D-0002.roi
# 020-1-59-adenoma-S-0003.zip
# 424-2-75-polyp-R-0002.jpg
# 239-2-82-adenoma-D-0001.jpg
# 034-1-56-adenoma-R-0001.roi
# 365-2-72-adenoma-S-0002.roi
# 467-2-55-adenoma-R-0002.jpg
# 116-2-69-adenoma-D-0001.jpg
# 355-1-69-adenoma-T-0001.roi
# 390-1-68-adenoma-T-0003.jpg
# 333-2-73-adenoma-S-0001.jpg
# 393-2-77-adenoma-S-0002.roi
# 130-1-63-adenoma-C-0001.roi
# 279-1-49-polyp-D-0003.jpg
# 100-1-76-polyp-S-0006.jpg
# 226-2-72-adenoma-D-0000.roi
# 093-1-62-polyp-S-0001.jpg
# 236-1-64-adenoma-A-0000.jpg
# 232-2-71-adenoma-D-0000.jpg
# 239-2-82-adenoma-D-0001.roi
# 424-2-75-polyp-R-0002.roi
# 313-1-72-adenoma-D-0002.jpg
# 087-1-72-adenoma-T-0001.jpg
# 166-1-56-polyp-T-0003.jpg
# 431-1-73-polyp-S-0002.roi
# 481-1-72-adenoma-S-0001.jpg
# 286-2-66-adenoma-D-0002.jpg
# 111-1-78-adenoma-D-0000.jpg
# 083-2-71-adenoma-S-0008.jpg
# 304-1-50-adenoma-T-0002.jpg
# 388-1-68-adenoma-A-0001.jpg
# 377-2-67-adenoma-C-0001.roi
# 376-1-60-adenoma-T-0001.roi
# 457-1-70-adenoma-A-0001.jpg
# 372-2-51-adenoma-S-0001.roi
# 383-1-73-adenoma-AV50-0002.roi
# 032-2-55-adenoma-T-0000.jpg
# 519-2-72-adenoma-T-0001.jpg
# 350-1-55-adenoma-T-0002.jpg
# 353-1-75-adenoma-S-0002.jpg
# 423-1-59-adenoma-S-0002.roi
# 024-1-80-adenoma-T-0000.jpg
# 543-1-82-adenoma-A-0001.jpg
# 241-1-65-adenoma-A-0000.jpg
# 018-1-59-adenoma-S-0001.roi
# 359-2-77-adenoma-D-0001.roi
# 017-1-59-adenoma-S-0000.roi
# 182-1-65-adenoma-D-0000.jpg
# 082-2-71-adenoma-S-0003.roi
# 187-1-80-adenoma-A-0001.roi
# 545-1-83-adenoma-A-0002.jpg
# 451-2-76-adenoma-S-0001.roi
# 295-1-65-adenoma-R-0001.jpg
# 132-1-61-polyp-D-0000.roi
# 534-1-60-adenoma-S-0001.jpg
# 462-1-70-adenoma-T-0002.jpg
# 371-1-56-adenoma-A-0001.roi
# 421-2-67-adenoma-A-0002.roi
# 065-1-52-adenoma-T-0000.jpg
# 445-2-84-adenoma-D-0003.jpg
# 479-2-49-polyp-0001.roi
# 269-1-62-adenoma-A-0001.jpg
# 358-1-65-adenoma-A-0002.roi
# 384-2-59-adenoma-HF-0001.jpg
# 334-1-72-adenoma-T-0001.roi
# 503-1-35-polyp-A-0001.jpg
# 362-2-77-adenoma-R-0003.roi
# 330-1-62-adenoma-A-0001.roi
# 302-1-81-adenoma-S-0002.jpg
# 506-2-51-polyp-RS-0003.roi
# 069-1-62-adenoma-S-0001.jpg
# 378-1-59-adenoma-S-0001.jpg
# 474-1-52-adenoma-A-0001.roi
# 075-1-58-adenoma-D-0000.jpg
# 224-2-57-adenoma-SDJ-0001.jpg
# 310-2-40-polyp-A-0002.jpg
# 546-1-83-adenoma-T-0005.roi
# 036-1-74-adenoma-T-0000.roi
# 386-1-77-adenoma-A-0001.roi
# 464-1-51-polyp-A-0001.roi
# 001-1-54-adenoma-D-0000.roi
# 456-2-76-adenoma-T-0004.roi
# 391-1-58-polyp-S-0001.roi
# 133-1-60-polyp-30cm-0000.jpg
# 140-2-64-adenoma-S-0001.jpg
# 073-2-47-adenoma-T-0000.roi
# 460-1-70-adenoma-D-0006.jpg
# 155-2-68-adenoma-R-0002.jpg
# 344-1-78-adenoma-A-0001.roi
# 514-1-59-adenoma-S-0002.roi
# 524-1-71-adenoma-D-0003.jpg
# 444-2-84-adenoma-A-0001.roi
# 012-2-57-adenoma-S-0000.roi
# 085-2-71-adenoma-S-0010.jpg
# 058-2-50-adenoma-R-0001.roi
# 450-1-75-2-adenoma-0002.roi
# 387-1-77-adenoma-D-0002.jpg
# 307-2-81-adenoma-S-0001.jpg
# 054-2-58-adenoma-S-0000.roi
# 480-2-62-adenoma-RS-0001.jpg
# 205-2-52-adenoma-T-0002.jpg
# 505-2-51-polyp-RS-0002.roi
# 526-1-71-adenoma-T-0002.jpg
# 354-1-75-adenoma-S-0003.roi
# 260-2-77-adenoma-S-0002.roi
# 518-1-47-adenoma-T-0001.roi
# 499-2-68-adenoma-A-0001.roi
# 452-2-76-adenoma-S-0005.jpg
# 427-1-54-adenoma-S-0002.roi
# 428-1-54-adenoma-S-0003.roi
# 201-1-62-adenoma-C-0001.jpg
# 530-1-58-adenoma-A-0001.jpg
# 050-2-76-adenoma-S-0000.roi
# 228-2-72-adenoma-T-0003.jpg
# 138-1-54-adenoma-S-0000.roi
# 084-2-71-adenoma-S-0009.roi
# 542-2-52-adenoma-T-0001.roi
# 436-1-56-adenoma-R-0002.roi
# 416-1-57-adenoma-A-0002.jpg
# 471-1-65-adenoma-S-0003.jpg
# 048-1-57-adenoma-R-0000.jpg
# 265-2-50-adenoma-T-0002.jpg
# 004-1-57-polyp-D-0001.roi
# 096-1-76-adenoma-A-0000.roi
# 299-1-65-adenoma-S-0005.roi
# 398-2-71-adenoma-S-0002.jpg
# 385-1-72-polyp-S-0001.roi
# 213-2-53-adenoma-T-0001.roi
# 045-1-76-adenoma-R-0005.jpg
# 169-2-62-adenoma-R-0000.roi
# 343-1-58-adenoma-A-0001.jpg
# 009-2-67-adenoma-T-0000.roi
# 233-2-71-adenoma-S-0001.jpg
# 414-1-58-adenoma-A-0001.jpg
# 528-1-82-adenoma-D-0001.jpg
# 014-1-47-adenoma-T-0000.roi
# 063-1-59-polyp-S-0001.jpg
# 276-1-52-adenoma-T-0002.roi
# 521-2-60-adenoma-S-0001.roi
# 312-1-54-adenoma-S-0001.roi
# 006-2-57-adenoma-S-0001.jpg
# 435-1-68-adenoma-A-0001.roi
# 137-1-42-adenoma-S-0000.jpg
# 434-1-64-adenoma-T-0001.jpg
# 290-1-54-adenoma-A-0002.jpg
# 110-1-66-adenoma-A-0000.roi
# 061-1-52-adenoma-T-0001.jpg
# 520-2-59-adenoma-T-0001.jpg
# 317-1-58-adenoma-T-0001.roi
# 492-1-55-polyp-S-0001.jpg
# 406-1-74-adenoma-T-0002.roi
# 469-2-59-adenoma-S-0001.roi
# 544-1-82-adenoma-HF-0004.jpg
# 507-2-51-polyp-RS-0004.jpg
# 021-1-72-adenoma-S-0001.roi
# 253-2-50-adenoma-A-0001.roi
# 280-2-46-adenoma-A-0001.jpg
# 397-2-71-adenoma-S-0001.jpg
# 315-1-72-polyp-R-0006.roi
# 495-2-56-adenoma-S-0001.roi
# 262-1-79-adenoma-A-0001.roi
# 408-1-53-adenoma-A-0001.roi
# 497-2-47-polyp-T-0001.jpg
# 143-1-60-adenoma-A-0000.jpg
# 115-1-78-polyp-R-0008.jpg
# 144-1-60-adenoma-T-0001.roi
# 473-2-70-adenoma-A-0001.roi
# 303-1-50-adenoma-T-0001.roi
# 400-2-62-adenoma-A-0002.roi
# 249-1-21-polyp-A-0000.roi
# 079-2-73-polyp-A-0003.jpg
# 363-1-49-adenoma-T-0001.jpg
# 510-2-60-adenoma-T-0001.jpg
# 525-1-71-adenoma-T-0001.roi
# 062-1-59-adenoma-T-0000.jpg
# 243-1-49-tumor-S-0002.jpg
# 379-1-48-adenoma-S-0001.roi
# 197-1-67-adenoma-C-0000.roi
# 360-2-77-adenoma-D-0002.jpg
# 039-2-75-adenoma-R-0002.roi
# 193-2-54-adenoma-A-0000.roi
# 337-2-75-adenoma-T-0001.jpg
# 244-1-61-adenoma-A-0000.jpg
# 489-1-63-polyp-S-0003.jpg
# 415-1-57-adenoma-A-0001.roi
# 517-1-71-adenoma-T-0001.jpg
# 117-2-69-adenoma-S-0003.jpg
# 207-1-27-adenoma-T-0001.jpg
# 031-1-74-polyp-H-0001.roi
# 173-1-61-polyp-S-0000.roi
# 217-1-77-adenoma-T-0004.roi
# 175-2-77-adenoma-A-0001.roi
# 225-2-75-adenoma-A-0000.roi
# ../Data/Split_Data/test/abnormal
# Processing directory: ../Data/Split_Data/test/abnormal
# 482-1-53-1-A.jpg
# 014-2-71-1-C.jpg
# 504-2-50-1-C.jpg
# 256-1-54-1-HF.jpg
# 029-2-55-1-T.jpg
# 117-1-60-1-A.jpg
# 418-1-64-1-S.jpg
# 423-1-49-1-D.jpg
# 330-2-55-1-A.jpg
# 109-2-59-1-C.jpg
# 329-1-75-1-A.jpg
# 422-1-49-1-C.jpg
# 166-2-38-1-A.jpg
# 288-1-50-1-R.jpg
# 380-2-56-1-HF.jpg
# 126-1-69-1-C.jpg
# 384-2-56-1-T.jpg
# 516-2-55-1-HF.jpg
# 285-2-78-1-S.jpg
# 218-2-69-1-D.jpg
# 413-1-64-1-A.jpg
# 059-2-69-1-T.jpg
# 172-2-76-1-C.jpg
# 401-1-65-1-D.jpg
# 078-1-34-1-A.jpg
# 137-1-58-1-R.jpg
# 398-2-53-1-S.jpg
# 181-2-64-1-S.jpg
# 052-1-58-1-S.jpg
# 414-1-64-1-C.jpg
# 439-2-76-1-D.jpg
# 296-1-59-1-T.jpg
# 186-2-42-1-T.jpg
# 357-1-68-1-C.jpg
# 290-1-50-1-T.jpg
# 205-1-61-1-D.jpg
# 234-1-56-1-HF.jpg
# 035-2-76-1-A.jpg
# 280-1-54-1-S.jpg
# 407-2-69-1-R.jpg
# 281-1-54-1-T.jpg
# 298-1-70-1-R.jpg
# 519-2-55-1-SF.jpg
# 508-1-45-1-D.jpg
# 230-2-56-1-D.jpg
# 305-1-56-1-R.jpg
# 495-2-48-1-A.jpg
# 226-2-75-1-T.jpg
# 361-1-68-1-T.jpg
# 041-1-58-1-R.jpg
# 405-2-69-1-D.jpg
# 098-1-49-1-A.jpg
# 338-2-45-1-S.jpg
# 424-1-49-1-HF.jpg
# 492-2-62-1-T.jpg
# 294-1-59-1-R.jpg
# 171-2-76-1-A.jpg
# 225-2-75-1-S.jpg
# 404-2-69-1-A.jpg
# 010-1-79-1-HF.jpg
# 133-1-58-1-A.jpg
# 168-2-38-1-R.jpg
# 072-2-62-1-A.jpg
# 184-2-42-1-D.jpg
# 403-1-65-1-S.jpg
# 417-1-64-1-R.jpg
# 042-1-58-1-S.jpg
# 466-1-52-1-R.jpg
# 237-2-52-1-D.jpg
# 002-2-54-1-R.jpg
# 307-1-56-1-T.jpg
# 292-1-59-1-D.jpg
# 019-1-63-1-R.jpg
# 245-1-58-1-R.jpg
# 044-1-28-1-A.jpg
# 139-1-58-1-T.jpg
# 469-2-52-1-D.jpg
# 494-2-46-1-T.jpg
# 222-2-59-1-R.jpg
# 105-2-61-1-R.jpg
# 214-1-73-1-R.jpg
# 272-1-58-1-A.jpg
# 426-1-49-1-S.jpg
# 347-1-55-1-D.jpg
# 335-2-55-1-T.jpg
# 353-1-44-1-R.jpg
# 370-2-82-1-T.jpg
# 079-2-55-1-A.jpg
# 486-1-53-1-T.jpg
# 103-2-61-1-A.jpg
# 012-1-79-1-S.jpg
# 092-1-67-1-C.jpg
# 223-1-54-1-D.jpg
# 375-1-50-1-S.jpg
# 125-1-69-1-A.jpg
# 081-2-78-1-SF.jpg
# 320-2-63-1-D.jpg
# 493-2-46-1-D.jpg
# 195-2-66-1-HF.jpg
# 197-2-66-1-S.jpg
# 383-2-56-1-SDJ.jpg
# 045-1-28-1-C.jpg
# 352-1-44-1-D.jpg
# 273-1-58-1-C.jpg
# 481-1-29-1-T.jpg
# 114-2-74-1-HF.jpg
# 061-1-64-1-R.jpg
# 365-1-55-1-R.jpg
# 480-1-29-1-S.jpg
# 381-2-56-1-R.jpg
# Patch extraction and visualization complete.

# %%
import pandas as pd
import numpy as np
import cv2
from read_roi import read_roi_file
import os
import random

def detect_features_in_channel(channel):
    features = cv2.goodFeaturesToTrack(channel, maxCorners=200, qualityLevel=0.01, minDistance=50, blockSize=300)
    if features is not None:
        return np.int0(features)
    else:
        return np.array([])

def filter_close_points(features, min_dist=100):
    if features.ndim == 3:
        features = features.reshape(-1, 2)
    
    filtered_points = []

    for feature in features:
        if not filtered_points:
            filtered_points.append(feature)
            continue

        dists = np.sqrt(np.sum((np.array(filtered_points) - feature) ** 2, axis=1))

        if np.all(dists >= min_dist):
            filtered_points.append(feature)

    return np.array(filtered_points)

def bounding_box(roi_file_path):
    roi = read_roi_file(roi_file_path)
    for box_info in roi.values():
        if box_info['type'] == 'rectangle':
            left = box_info['left']
            top = box_info['top']
            width = box_info['width']
            height = box_info['height']
    return left, top, width, height

def extract_patch(image, center_x, center_y, patch_size):
    half_width, half_height = patch_size[0] // 2, patch_size[1] // 2
    patch = image[
        center_y - half_height:center_y + half_height,
        center_x - half_width:center_x + half_width
    ]
    return patch

def extract_patches_from_abnormal(image_path, roi_file_path, patch_size=(100, 100)):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    left, top, width, height = bounding_box(roi_file_path)
    roi_region = gray_image[top:top+height, left:left+width]
    
    features = detect_features_in_channel(roi_region)
    
    if len(features) > 0:
        features[:, 0] += left
        features[:, 1] += top

        salient_points = filter_close_points(features)
        
        if len(salient_points) > 0:
            center_x, center_y = np.mean(salient_points, axis=0).astype(int)
            patch = extract_patch(image, center_x, center_y, patch_size)
            visualize_patch(image, center_x, center_y, patch_size)
            return patch, image
    
    center_x, center_y = left + width // 2, top + height // 2
    patch = extract_patch(image, center_x, center_y, patch_size)
    visualize_patch(image, center_x, center_y, patch_size)
    
    return patch, image

def extract_patches_from_normal(image_path, patch_size=(100, 100)):
    image = cv2.imread(image_path)
    h, w, _ = image.shape
    
    middle_x_range = (w // 4, 3 * w // 4)
    middle_y_range = (h // 4, 3 * h // 4)
    
    patches = []
    visualized_images = []
    for _ in range(2):
        center_x = random.randint(middle_x_range[0], middle_x_range[1])
        center_y = random.randint(middle_y_range[0], middle_y_range[1])
        patch = extract_patch(image, center_x, center_y, patch_size)
        patches.append(patch)
        
        visualize_patch(image, center_x, center_y, patch_size)
        visualized_images.append(image.copy())
    
    return patches, visualized_images

def visualize_patch(image, center_x, center_y, patch_size):
    half_width, half_height = patch_size[0] // 2, patch_size[1] // 2
    top_left = (center_x - half_width, center_y - half_height)
    bottom_right = (center_x + half_width, center_y + half_height)
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

def save_patches(patches, output_dir, base_name):
    for i, patch in enumerate(patches):
        patch_filename = f"{base_name}_patch_{i}.png"
        patch_path = os.path.join(output_dir, patch_filename)
        cv2.imwrite(patch_path, patch)

def save_visualized_images(images, output_dir, base_name):
    for i, img in enumerate(images):
        visualized_filename = f"{base_name}_visualized_{i}.png"
        visualized_path = os.path.join(output_dir, visualized_filename)
        cv2.imwrite(visualized_path, img)

def process_directory(input_dir, output_dir, visualized_dir, is_abnormal=False, patch_size=(100, 100)):
    print(f"Processing directory: {input_dir}")
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            image_path = os.path.join(input_dir, filename)
            print(f'ImagePath:{image_path}')
            base_name = os.path.splitext(filename)[0]
            print(f'BaseName:{base_name}')
            
            if is_abnormal:
                roi_file_path = os.path.join(input_dir, f"{base_name}.roi")
                print(f'RoiFilePath:{roi_file_path}')
                if os.path.exists(roi_file_path):
                    patch, visualized_image = extract_patches_from_abnormal(image_path, roi_file_path, patch_size)
                    print(f'Patch:{patch}')
                    save_patches([patch], output_dir, base_name)
                    save_visualized_images([visualized_image], visualized_dir, base_name)
            else:
                patches, visualized_images = extract_patches_from_normal(image_path, patch_size)
                print(f'Patches:{patches}')
                save_patches(patches, output_dir, base_name)
                save_visualized_images(visualized_images, visualized_dir, base_name)

# Define train and test directories
train_dir = 'Data/Split_Data/train'
test_dir = 'Data/Split_Data/test'

# Process the normal and abnormal directories in both train and test directories
for data_dir in [train_dir, test_dir]:
    for class_type in ['normal', 'abnormal']:
        input_dir = os.path.join(data_dir, class_type)
        print(input_dir)
        output_dir = os.path.join('Processed_Data', os.path.basename(data_dir), class_type)
        visualized_dir = os.path.join('Visualized_Data', os.path.basename(data_dir), class_type)
        os.makedirs(output_dir, exist_ok=True)
        os.makedirs(visualized_dir, exist_ok=True)
        process_directory(input_dir, output_dir, visualized_dir, is_abnormal=(class_type == 'abnormal'))

print("Patch extraction and visualization complete.")
# Out:
# Data/Split_Data/train/normal
# Processing directory: Data/Split_Data/train/normal
# Data/Split_Data/train/abnormal
# Processing directory: Data/Split_Data/train/abnormal
# Data/Split_Data/test/normal
# Processing directory: Data/Split_Data/test/normal
# Data/Split_Data/test/abnormal
# Processing directory: Data/Split_Data/test/abnormal
# Patch extraction and visualization complete.

# %%
import pandas as pd
import numpy as np
import cv2
from read_roi import read_roi_file
import os
import random

def detect_features_in_channel(channel):
    features = cv2.goodFeaturesToTrack(channel, maxCorners=200, qualityLevel=0.01, minDistance=50, blockSize=300)
    if features is not None:
        return np.int0(features)
    else:
        return np.array([])

def filter_close_points(features, min_dist=100):
    if features.ndim == 3:
        features = features.reshape(-1, 2)
    
    filtered_points = []

    for feature in features:
        if not filtered_points:
            filtered_points.append(feature)
            continue

        dists = np.sqrt(np.sum((np.array(filtered_points) - feature) ** 2, axis=1))

        if np.all(dists >= min_dist):
            filtered_points.append(feature)

    return np.array(filtered_points)

def bounding_box(roi_file_path):
    roi = read_roi_file(roi_file_path)
    for box_info in roi.values():
        if box_info['type'] == 'rectangle':
            left = box_info['left']
            top = box_info['top']
            width = box_info['width']
            height = box_info['height']
    return left, top, width, height

def extract_patch(image, center_x, center_y, patch_size):
    half_width, half_height = patch_size[0] // 2, patch_size[1] // 2
    patch = image[
        center_y - half_height:center_y + half_height,
        center_x - half_width:center_x + half_width
    ]
    return patch

def extract_patches_from_abnormal(image_path, roi_file_path, patch_size=(100, 100)):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    left, top, width, height = bounding_box(roi_file_path)
    roi_region = gray_image[top:top+height, left:left+width]
    
    features = detect_features_in_channel(roi_region)
    
    if len(features) > 0:
        features[:, 0] += left
        features[:, 1] += top

        salient_points = filter_close_points(features)
        
        if len(salient_points) > 0:
            center_x, center_y = np.mean(salient_points, axis=0).astype(int)
            patch = extract_patch(image, center_x, center_y, patch_size)
            visualize_patch(image, center_x, center_y, patch_size)
            return patch, image
    
    center_x, center_y = left + width // 2, top + height // 2
    patch = extract_patch(image, center_x, center_y, patch_size)
    visualize_patch(image, center_x, center_y, patch_size)
    
    return patch, image

def extract_patches_from_normal(image_path, patch_size=(100, 100)):
    image = cv2.imread(image_path)
    h, w, _ = image.shape
    
    middle_x_range = (w // 4, 3 * w // 4)
    middle_y_range = (h // 4, 3 * h // 4)
    
    patches = []
    visualized_images = []
    for _ in range(2):
        center_x = random.randint(middle_x_range[0], middle_x_range[1])
        center_y = random.randint(middle_y_range[0], middle_y_range[1])
        patch = extract_patch(image, center_x, center_y, patch_size)
        patches.append(patch)
        
        visualize_patch(image, center_x, center_y, patch_size)
        visualized_images.append(image.copy())
    
    return patches, visualized_images

def visualize_patch(image, center_x, center_y, patch_size):
    half_width, half_height = patch_size[0] // 2, patch_size[1] // 2
    top_left = (center_x - half_width, center_y - half_height)
    bottom_right = (center_x + half_width, center_y + half_height)
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

def save_patches(patches, output_dir, base_name):
    for i, patch in enumerate(patches):
        patch_filename = f"{base_name}_patch_{i}.png"
        patch_path = os.path.join(output_dir, patch_filename)
        cv2.imwrite(patch_path, patch)

def save_visualized_images(images, output_dir, base_name):
    for i, img in enumerate(images):
        visualized_filename = f"{base_name}_visualized_{i}.png"
        visualized_path = os.path.join(output_dir, visualized_filename)
        cv2.imwrite(visualized_path, img)

def process_abnormal_directory(input_dir, output_dir, visualized_dir, patch_size=(100, 100)):
    print(f"Processing abnormal directory: {input_dir}")
    if not os.path.exists(input_dir):
        print(f"Directory does not exist: {input_dir}")
        return

    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            image_path = os.path.join(input_dir, filename)
            base_name = os.path.splitext(filename)[0]
            roi_file_path = os.path.join(input_dir, f"{base_name}.roi")
            if os.path.exists(roi_file_path):
                patch, visualized_image = extract_patches_from_abnormal(image_path, roi_file_path, patch_size)
                save_patches([patch], output_dir, base_name)
                save_visualized_images([visualized_image], visualized_dir, base_name)
            else:
                print(f"ROI file does not exist: {roi_file_path}")

def process_normal_directory(input_dir, output_dir, visualized_dir, patch_size=(100, 100)):
    print(f"Processing normal directory: {input_dir}")
    if not os.path.exists(input_dir):
        print(f"Directory does not exist: {input_dir}")
        return

    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            image_path = os.path.join(input_dir, filename)
            base_name = os.path.splitext(filename)[0]
            patches, visualized_images = extract_patches_from_normal(image_path, patch_size)
            save_patches(patches, output_dir, base_name)
            save_visualized_images(visualized_images, output_dir, base_name)

# Define train and test directories
train_dir = 'Data/Split_Data/train'
test_dir = 'Data/Split_Data/test'

# Process the normal and abnormal directories in both train and test directories
for data_dir in [train_dir, test_dir]:
    for class_type in ['normal', 'abnormal']:
        input_dir = os.path.join(data_dir, class_type)
        output_dir = os.path.join('Processed_Data', os.path.basename(data_dir), class_type)
        visualized_dir = os.path.join('Visualized_Data', os.path.basename(data_dir), class_type)
        os.makedirs(output_dir, exist_ok=True)
        os.makedirs(visualized_dir, exist_ok=True)
        if class_type == 'abnormal':
            process_abnormal_directory(input_dir, output_dir, visualized_dir)
        else:
            process_normal_directory(input_dir, output_dir, visualized_dir)

print("Patch extraction and visualization complete.")
# Out:
# Processing normal directory: Data/Split_Data/train/normal
# Processing abnormal directory: Data/Split_Data/train/abnormal
# Processing normal directory: Data/Split_Data/test/normal
# Processing abnormal directory: Data/Split_Data/test/abnormal
# Patch extraction and visualization complete.

# %%
import os
import cv2
import numpy as np
from read_roi import read_roi_file
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt

def detect_features_in_channel(channel):
    features = cv2.goodFeaturesToTrack(channel, maxCorners=200, qualityLevel=0.01, minDistance=50, blockSize=300)
    if features is not None:
        return np.int0(features)
    else:
        return np.array([])

def filter_close_points(features, min_dist=100):
    if features.ndim == 3:
        features = features.reshape(-1, 2)
    
    filtered_points = []

    for feature in features:
        if not filtered_points:
            filtered_points.append(feature)
            continue

        dists = np.sqrt(np.sum((np.array(filtered_points) - feature) ** 2, axis=1))

        if np.all(dists >= min_dist):
            filtered_points.append(feature)

    return np.array(filtered_points)

def bounding_box(roi_file_path):
    roi = read_roi_file(roi_file_path)
    for box_info in roi.values():
        if box_info['type'] == 'rectangle':
            left = box_info['left']
            top = box_info['top']
            width = box_info['width']
            height = box_info['height']
    return left, top, width, height

def extract_and_save_patches_abnormal(folder, output_folder, ideal_patch_size=(275, 300)):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    for filename in os.listdir(folder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(folder, filename)
            image = cv2.imread(image_path)
            roi_path = os.path.splitext(image_path)[0] + ".roi"

            if os.path.exists(roi_path):
                blue, green, red = cv2.split(image)
                features_blue = detect_features_in_channel(blue)
                features_green = detect_features_in_channel(green)
                features_red = detect_features_in_channel(red)
                features_combined = np.vstack([f.reshape(-1, 2) for f in [features_blue, features_green, features_red] if f.size > 0])
                features_combined = np.unique(features_combined, axis=0)
                features_combined = filter_close_points(features_combined)

                if features_combined.size == 0:
                    continue  # Skip if no features found

                for point in features_combined:
                    cv2.circle(image, (int(point[0]), int(point[1])), radius=5, color=(255, 0, 0), thickness=-1)

                gt_left, gt_top, gt_width, gt_height = bounding_box(roi_path)
                cv2.rectangle(image, (gt_left, gt_top), (gt_left + gt_width, gt_top + gt_height), (0, 255, 0), 3)

                gt_center = np.array([[gt_left + gt_width / 2, gt_top + gt_height / 2]])
                distances = cdist(features_combined, gt_center, metric='euclidean')
                closest_point_index = np.argmin(distances)
                closest_point = features_combined[closest_point_index]

                sp_start_x = max(int(closest_point[0] - ideal_patch_size[1] / 2), 0)
                sp_start_y = max(int(closest_point[1] - ideal_patch_size[0] / 2), 0)
                sp_end_x = min(sp_start_x + ideal_patch_size[1], image.shape[1])
                sp_end_y = min(sp_start_y + ideal_patch_size[0], image.shape[0])

                cv2.rectangle(image, (sp_start_x, sp_start_y), (sp_end_x, sp_end_y), (0, 0, 0), 3)

                salient_patch = image[sp_start_y:sp_end_y, sp_start_x:sp_end_x]
                salient_patch_name = f"{os.path.splitext(os.path.basename(image_path))[0]}_salient_patch_{sp_start_x}_{sp_start_y}.png"
                salient_patch_path = os.path.join(output_folder, salient_patch_name)

                cv2.imwrite(salient_patch_path, salient_patch)

def extract_and_save_patches_normal(folder, output_folder, ideal_patch_size=(275, 300)):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(folder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(folder, filename)
            image = cv2.imread(image_path)
            h, w, _ = image.shape

            middle_x_range = (w // 4, 3 * w // 4)
            middle_y_range = (h // 4, 3 * h // 4)

            patches = []
            for _ in range(2):
                center_x = random.randint(middle_x_range[0], middle_x_range[1])
                center_y = random.randint(middle_y_range[0], middle_y_range[1])
                sp_start_x = max(int(center_x - ideal_patch_size[1] / 2), 0)
                sp_start_y = max(int(center_y - ideal_patch_size[0] / 2), 0)
                sp_end_x = min(sp_start_x + ideal_patch_size[1], w)
                sp_end_y = min(sp_start_y + ideal_patch_size[0], h)

                patch = image[sp_start_y:sp_end_y, sp_start_x:sp_end_x]
                patches.append(patch)
                patch_name = f"{os.path.splitext(os.path.basename(image_path))[0]}_normal_patch_{sp_start_x}_{sp_start_y}.png"
                patch_path = os.path.join(output_folder, patch_name)
                cv2.imwrite(patch_path, patch)

### Main Function to Process Both Normal and Abnormal Images:

def process_directories(train_dir, test_dir, output_dir, ideal_patch_size=(275, 300)):
    for data_dir in [train_dir, test_dir]:
        for class_type in ['normal', 'abnormal']:
            input_dir = os.path.join(data_dir, class_type)
            output_sub_dir = os.path.join(output_dir, os.path.basename(data_dir), class_type)
            os.makedirs(output_sub_dir, exist_ok=True)

            if class_type == 'abnormal':
                extract_and_save_patches_abnormal(input_dir, output_sub_dir, ideal_patch_size)
            else:
                extract_and_save_patches_normal(input_dir, output_sub_dir, ideal_patch_size)

### Define Train and Test Directories:

train_dir = 'Data/Split_Data/train'
test_dir = 'Data/Split_Data/test'
output_dir = 'Processed_Patches'

### Process the Normal and Abnormal Directories:

process_directories(train_dir, test_dir, output_dir)

print("Patch extraction and visualization complete.")
# Out:
# Patch extraction and visualization complete.

# %%
import os
import cv2
import numpy as np
from read_roi import read_roi_file
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt

def detect_features_in_channel(channel):
    features = cv2.goodFeaturesToTrack(channel, maxCorners=200, qualityLevel=0.01, minDistance=50, blockSize=300)
    if features is not None:
        return np.int0(features)
    else:
        return np.array([])

def filter_close_points(features, min_dist=100):
    if features.ndim == 3:
        features = features.reshape(-1, 2)
    
    filtered_points = []

    for feature in features:
        if not filtered_points:
            filtered_points.append(feature)
            continue

        dists = np.sqrt(np.sum((np.array(filtered_points) - feature) ** 2, axis=1))

        if np.all(dists >= min_dist):
            filtered_points.append(feature)

    return np.array(filtered_points)

def bounding_box(roi_file_path):
    roi = read_roi_file(roi_file_path)
    for box_info in roi.values():
        if box_info['type'] == 'rectangle':
            left = box_info['left']
            top = box_info['top']
            width = box_info['width']
            height = box_info['height']
    return left, top, width, height

def visualize_and_save(image, output_path, title):
    plt.figure(figsize=(10, 5))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.savefig(output_path)
    plt.close()

def extract_and_save_patches_abnormal(folder, output_folder, visualization_folder, ideal_patch_size=(275, 300)):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(visualization_folder):
        os.makedirs(visualization_folder)
        
    for filename in os.listdir(folder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(folder, filename)
            image = cv2.imread(image_path)
            visualization_image = image.copy()
            roi_path = os.path.splitext(image_path)[0] + ".roi"

            if os.path.exists(roi_path):
                blue, green, red = cv2.split(image)
                features_blue = detect_features_in_channel(blue)
                features_green = detect_features_in_channel(green)
                features_red = detect_features_in_channel(red)
                features_combined = np.vstack([f.reshape(-1, 2) for f in [features_blue, features_green, features_red] if f.size > 0])
                features_combined = np.unique(features_combined, axis=0)
                features_combined = filter_close_points(features_combined)

                if features_combined.size == 0:
                    continue  # Skip if no features found

                for point in features_combined:
                    cv2.circle(visualization_image, (int(point[0]), int(point[1])), radius=5, color=(255, 0, 0), thickness=-1)

                gt_left, gt_top, gt_width, gt_height = bounding_box(roi_path)
                cv2.rectangle(visualization_image, (gt_left, gt_top), (gt_left + gt_width, gt_top + gt_height), (0, 255, 0), 3)

                gt_center = np.array([[gt_left + gt_width / 2, gt_top + gt_height / 2]])
                distances = cdist(features_combined, gt_center, metric='euclidean')
                closest_point_index = np.argmin(distances)
                closest_point = features_combined[closest_point_index]

                sp_start_x = max(int(closest_point[0] - ideal_patch_size[1] / 2), 0)
                sp_start_y = max(int(closest_point[1] - ideal_patch_size[0] / 2), 0)
                sp_end_x = min(sp_start_x + ideal_patch_size[1], image.shape[1])
                sp_end_y = min(sp_start_y + ideal_patch_size[0], image.shape[0])

                cv2.rectangle(visualization_image, (sp_start_x, sp_start_y), (sp_end_x, sp_end_y), (0, 0, 0), 3)

                salient_patch = image[sp_start_y:sp_end_y, sp_start_x:sp_end_x]
                salient_patch_name = f"{os.path.splitext(os.path.basename(image_path))[0]}_salient_patch_{sp_start_x}_{sp_start_y}.png"
                salient_patch_path = os.path.join(output_folder, salient_patch_name)

                cv2.imwrite(salient_patch_path, salient_patch)

                # Save visualization
                visualization_path = os.path.join(visualization_folder, f"{os.path.splitext(os.path.basename(image_path))[0]}_visualization.png")
                visualize_and_save(visualization_image, visualization_path, "Salient Patch and ROI")

def extract_and_save_patches_normal(folder, output_folder, visualization_folder, ideal_patch_size=(275, 300)):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(visualization_folder):
        os.makedirs(visualization_folder)

    for filename in os.listdir(folder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(folder, filename)
            image = cv2.imread(image_path)
            visualization_image = image.copy()
            h, w, _ = image.shape

            middle_x_range = (w // 4, 3 * w // 4)
            middle_y_range = (h // 4, 3 * h // 4)

            patches = []
            for _ in range(2):
                center_x = random.randint(middle_x_range[0], middle_x_range[1])
                center_y = random.randint(middle_y_range[0], middle_y_range[1])
                sp_start_x = max(int(center_x - ideal_patch_size[1] / 2), 0)
                sp_start_y = max(int(center_y - ideal_patch_size[0] / 2), 0)
                sp_end_x = min(sp_start_x + ideal_patch_size[1], w)
                sp_end_y = min(sp_start_y + ideal_patch_size[0], h)

                patch = image[sp_start_y:sp_end_y, sp_start_x:sp_end_x]
                patches.append(patch)
                patch_name = f"{os.path.splitext(os.path.basename(image_path))[0]}_normal_patch_{sp_start_x}_{sp_start_y}.png"
                patch_path = os.path.join(output_folder, patch_name)
                cv2.imwrite(patch_path, patch)

                cv2.rectangle(visualization_image, (sp_start_x, sp_start_y), (sp_end_x, sp_end_y), (0, 0, 0), 3)

            # Save visualization
            visualization_path = os.path.join(visualization_folder, f"{os.path.splitext(os.path.basename(image_path))[0]}_visualization.png")
            visualize_and_save(visualization_image, visualization_path, "Extracted Patches")

def process_directories(train_dir, test_dir, output_dir, visualization_dir, ideal_patch_size=(275, 300)):
    for data_dir in [train_dir, test_dir]:
        for class_type in ['normal', 'abnormal']:
            input_dir = os.path.join(data_dir, class_type)
            output_sub_dir = os.path.join(output_dir, os.path.basename(data_dir), class_type)
            visualization_sub_dir = os.path.join(visualization_dir, os.path.basename(data_dir), class_type)
            os.makedirs(output_sub_dir, exist_ok=True)
            os.makedirs(visualization_sub_dir, exist_ok=True)

            if class_type == 'abnormal':
                extract_and_save_patches_abnormal(input_dir, output_sub_dir, visualization_sub_dir, ideal_patch_size)
            else:
                extract_and_save_patches_normal(input_dir, output_sub_dir, visualization_sub_dir, ideal_patch_size)
    print("Patch extraction and visualization complete.")

# Define train and test directories
train_dir = 'Data/Split_Data/train'
test_dir = 'Data/Split_Data/test'
output_dir = 'Processed_Patches'
visualization_dir = 'Visualizations'

# Process the normal and abnormal directories
process_directories(train_dir, test_dir, output_dir, visualization_dir)

print("Patch extraction and visualization complete.")
# Out:
# Patch extraction and visualization complete.
